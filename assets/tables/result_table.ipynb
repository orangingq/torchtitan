# %%
import re
from textwrap import indent
import pandas as pd
from typing import Literal
from collections import Counter

# %%
def raw_to_dataframe(
                        raw: str, 
                        col_names: list[str] = ["pipeline", "method", "config", "mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
                        return_cols: list[str]|None = None,
                        numeric_cols: list[str] = ["mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
                        ) -> pd.DataFrame:
    """
    Parse the raw (CSV-like/tab/space separated) table text into a pandas DataFrame.
    Uses existing parse_raw_table. Optionally select a subset of columns.
    Coerces numeric-looking fields to numeric.
    """
    # Simple TSV parse with header skip: drop lines before "Base Pretrained Model"
    raw_lines = raw.splitlines()
    start_idx = 0
    for i, ln in enumerate(raw_lines):
        if "Base Pretrained Model" in ln:
            start_idx = i
            break
    lines = [ln for ln in raw_lines[start_idx:] if ln.strip()]
    rows = [ln.split('\t') for ln in lines]
    max_len = max((len(r) for r in rows), default=0)
    for r in rows:
        if len(r) < max_len:
            r.extend([""] * (max_len - len(r)))
    df = pd.DataFrame(rows)

    # Assign column names to a fixed schema
    # Trim or pad columns to match the schema length
    df = df.iloc[:, :len(col_names)]
    if df.shape[1] < len(col_names):
        df = pd.concat([df, pd.DataFrame([[""] * (len(col_names) - df.shape[1])] * len(df))], axis=1)
    df.columns = col_names

    # Convert numeric columns (skip text fields) with cleaning for %, commas, dashes
    for i, c in enumerate(numeric_cols):
        s = (
            df[c]
            .astype(str)
            .str.replace('%', '', regex=False)
            .str.replace(',', '', regex=False)
            .str.strip()
        )
        s = s.replace({'-': None, '--': None, '—': None, '–': None, '': None})

        # Coerce to numeric for comparison
        df[c] = pd.to_numeric(s, errors="coerce")

    if return_cols is not None:
        df = df[return_cols]

    return df

# Example: build a compact dataframe from the provided input_string
# try:
#     demo_df = raw_to_dataframe(input_string, \
#         # return_cols=["pipeline","method","avg_acc","freeze","throughput","tp_gain","mfu"]
#     )
#     display(demo_df)
# except NameError:
#     pass

# %%
def df_to_rows(df: pd.DataFrame, columns: list[str]|None = None, blank_nan: bool = True) -> list:
    """
    Convert a DataFrame to a list of row dictionaries.
    - columns: optional list to select/ordering of columns
    - blank_nan: when True, NaN/None are converted to "" in output
    """
    sub = df[columns].copy() if columns is not None else df.copy()
    if blank_nan:
        sub = sub.where(~sub.isna(), "")
    return sub.to_dict(orient="records")

# Example (only runs if demo_df exists)
# try:
#     demo_rows_from_df = df_to_rows(demo_df, \
#         columns=["pipeline","method","avg_acc","freeze","throughput","tp_gain","mfu"])
#     display(demo_rows_from_df[:2])
# except NameError:
#     pass

# %%
def style_cell(cell, cellcolor:str=''):
    cell = str(cell)
    if len(cell) == 0:
        cell = "--"
    if cell.endswith('.0'):
        cell = cell[:-2]
    elif cell.endswith('.0}'):
        cell = cell[:-3] + '}'
    return f"\cellcolor{{{cellcolor}}}{cell}" if len(cellcolor) > 0 else cell


def style_method(method, cellcolor:str=''):
    """Return LaTeX method cell with styling"""
    methodstyle = {
        "TimelyFreeze": "\TimelyFreeze{}",
        "TimelyFreeze+APF": "\scriptsize\quad +APF",
        "TimelyFreeze+AutoFreeze": "\scriptsize\quad +AutoFreeze"
    }
    return style_cell(methodstyle[method] if method in methodstyle.keys() else method, cellcolor)

def latex_datarow(r: dict,
                cellcolor:str='',
                columns:list[str] = ["avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu"],
                ):  
    latex = []
    for c in columns:
        latex.append(style_cell(r.get(c, ''), cellcolor))
    return " & ".join(latex) + r" \\"

# %%
def latex_pipeline(rows:list[dict], 
                    pipe: Literal["GPipe", "1F1B", "Interleaved 1F1B"],
                    cellcolordict: dict[str,str]={"TimelyFreeze": "gray!15", "TimelyFreeze+APF": "lightgray!10", "TimelyFreeze+AutoFreeze": "lightgray!10"},
                    datarow_cols: list[str] = ["avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu"],
                    ascending: dict[str,bool] = {"avg_acc": True, "acc_gain": True, "freeze": False, "throughput": True, "tp_gain": True, "mfu": True},
                    bold: dict[str,bool] = {"avg_acc": True, "acc_gain": True, "freeze": True, "throughput": True, "tp_gain": True, "mfu": True},
                    underline: dict[str,bool] = {"avg_acc": True, "acc_gain": True, "freeze": True, "throughput": True, "tp_gain": True, "mfu": True},
    )->str:
    """
    Convert rows of a pipeline into LaTeX table code.
    """
    assert rows[0]["pipeline"] == pipe, f"pipeline mismatch: {rows[0]['pipeline']} != {pipe}"

    l_pad, m_pad, r_pad = 30-(len(pipe)+2)//2, len(pipe) + 2, 30-(len(pipe)+3)//2
    latex = [
        "\n" + "%"*(l_pad + m_pad + r_pad),
        "%"*l_pad + " " + pipe + " " + "%"*r_pad,
        "%"*(l_pad + m_pad + r_pad),
    ]

    columns = set(rows[0].keys()) & set(datarow_cols)
    for c in columns:
        ascending_flag, bold_flag, underline_flag = ascending.get(c, True), bold.get(c, True), underline.get(c, True)
        if bold_flag or underline_flag:
            values = {i:r[c] for i, r in enumerate(rows) \
                if (r['method'] != '' and r['method'] != 'No Freezing') \
                        and (isinstance(r[c], (int, float)) or r[c].isnumeric())}
            if len(values) > 1:
                best, second_best = sorted(values.values(), reverse=ascending_flag)[:2]
            is_best = {k:v == best for k,v in values.items()}
            is_second_best = {k:v == second_best for k,v in values.items()}
            print('c:', c, 'values:', values.values(), 'best:', best, 'second_best:', second_best)
            for k,v in values.items():
                if bold_flag and is_best[k]:
                    rows[k][c] = r"\textbf{"+str(v)+"}"
                elif underline_flag and is_second_best[k]:
                    rows[k][c] = r"\underline{"+str(v)+"}"

    for r in rows:
        if r["pipeline"] == pipe:
            pcell = r"\multirow{" + str(len(rows)) + r"}{*}{\makecell[c]{" + pipe.replace(' ', r'\\') + r"}}"
        else:
            pcell = ""
        method = r['method']
        cellcolor = cellcolordict.get(method, '')
        latex.append(f"{pcell} & {style_method(method, cellcolor)} & {latex_datarow(r, cellcolor, datarow_cols)}")            

        # Add a line to separate No Freezing baseline from other methods
        if method == "No Freezing":
            num_cols = latex[-1].count("&")+1
            latex.append(r"\thincline{2-" + str(num_cols) + "}")

    print(f"pipe: {pipe}, latex: {latex}")
    return '\n'.join(latex) + "\n\hline"

# %%
def latex_table(rows,
                datarow_cols: list[str] = ["avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu"],
                header:str="",
                footer:str="",
                ):
    """
    Convert parsed rows into LaTeX table code.
    """
    latex = [header, '\hline']
    pipelines = {}
    curr_pipe = None
    for r in rows:
        if r["pipeline"] != '' and r["pipeline"] != curr_pipe:
            print(f"curr_pipe: {curr_pipe}, r: {r}")
            if curr_pipe in ["GPipe", "1F1B", "Interleaved 1F1B"]:
                latex.append(latex_pipeline(pipelines[curr_pipe], curr_pipe, datarow_cols=datarow_cols))
            elif curr_pipe == 'Base Pretrained Model':
                latex.append('\multicolumn{2}{c|}{Base Pretrained Model} & ' + latex_datarow(pipelines[curr_pipe][0], columns=datarow_cols))
                latex.append(r'\hline')
            curr_pipe = r["pipeline"]
            pipelines[curr_pipe] = [r]
        else:
            pipelines[curr_pipe].append(r)
    if curr_pipe in ["GPipe", "1F1B", "Interleaved 1F1B"]:
        latex.append(latex_pipeline(pipelines[curr_pipe], curr_pipe, datarow_cols=datarow_cols) + "\n")
    latex.append(footer)
    print("final latex: ", latex)
    return "\n".join(latex)

# %%
def raw_to_latex_table(raw, 
                        col_names: list[str] = ["pipeline", "method", "config", "mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
                        numeric_cols: list[str] = ["mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
                        columns:list[str] = ["pipeline","method","avg_acc","acc_gain","freeze","throughput","tp_gain","mfu"],
                        datarow_cols: list[str] = ["avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu"],
                        header:str="",
                        footer:str=""
                        ):
    df = raw_to_dataframe(raw, col_names=col_names, numeric_cols=numeric_cols)
    rows = df_to_rows(df, columns=columns)
    return latex_table(rows, datarow_cols=datarow_cols, header=header, footer=footer)

# %% [markdown]
# ## 1B Acc <-> Thp

# %%
def main_result_header(caption:str="Some Fancy Caption.") -> str:
    return r"""
\begin{table*}[t]
\renewcommand{\arraystretch}{1}
\centering
\caption{""" + caption + r"""}
\resizebox{\textwidth}{!}{
\begin{tabular}{cl|ccc|ccc}

%%%%% header %%%%%
\hline
\multirow{2}{*}{\makecell[c]{Pipeline \\ Schedule}} &
\multicolumn{1}{c|}{\multirow{2}{*}{\makecell[c]{Freeze \\ Method}}} &
\multicolumn{3}{c|}{Accuracy Preservation} &
\multicolumn{3}{c}{Time Efficiency} \\
\cline{3-5} \cline{6-8}
& & Avg. Acc.↑ & Acc. Gain↑ & Freeze Ratio↓ & Throughput↑ & Th. Gain↑ & MFU↑ \\

"""

def main_result_footer(label:str="some_fancy_label") -> str:
    return r"""
\end{tabular}}
\label{tab:""" + label.replace(" ", "_") + r"""}
\end{table*}
"""

# %%
caption = "Comparison of freezing methods under different pipeline schedules (LLaMA-1B)."
label = "llama1b"
output_file = label + "_table.txt"

input_string = """
"Pipeline 
Schedule"	Freeze Method		Accuracy Preservation							Time Efficiency			
			"MMLU
(5 shots)
 ↑"	"HellaSwag
 ↑"	"ARC-C
(10 shots)
 ↑"	"TruthfulQA
 ↑"	"Average
Acc.↑"	"Accuracy
Gain (%) ↑"	"Avg. Freeze 
Ratio (%) ↓"	"Avg. 
Throughput 
(token/s) ↑"	"Throughput
Gain (%) ↑"	Avg. mfu (%) ↑	"Avg. Batch
Time (s) ↓"
Base Pretrained Model			31.99%	47.75%	36.95%	23.01%	34.93%		-				
GPipe	No Freezing		32.54%	49.28%	37.37%	28.76%	36.99%	2.06%	0.00%	7022 	-	16.20 	4.67 
	APF	th=0.05	32.27%	48.27%	37.20%	24.72%	35.62%	0.69%	78.97%	9466 	34.79 	21.77 	3.46 
	AutoFreeze	p=80%	30.96%	48.32%	36.69%	26.56%	35.63%	0.71%	60.37%	7586 	8.03 	17.45 	4.32 
	TimelyFreeze	mfr=0.8	32.46%	48.22%	36.86%	25.83%	35.84%	0.92%	62.39%	9855 	40.34 	22.80 	3.32 
	TimelyFreeze+APF	mfr=0.8, th=0.05	32.33%	48.16%	37.12%	25.09%	35.68%	0.75%	60.91%	9916 	41.21 	22.90 	3.30 
	TimelyFreeze+AutoFreeze	mfr=0.8, p=80%	32.07%	48.14%	37.12%	25.58%	35.73%	0.80%	61.38%	9806 	39.64 	22.77 	3.34 
1F1B	No Freezing		31.23%	49.88%	37.71%	27.54%	36.59%	1.67%	0.00%	7121 	-	16.43 	4.60 
	APF	th=0.01	32.59%	48.37%	37.03%	25.46%	35.86%	0.94%	68.89%	8004 	12.40 	18.43 	4.09 
	AutoFreeze	p=80%	30.69%	47.80%	37.63%	25.34%	35.37%	0.44%	46.79%	7397 	3.87 	17.03 	4.43 
	TimelyFreeze	mfr=0.8	32.27%	49.06%	37.97%	27.54%	36.71%	1.79%	69.30%	8592 	20.66 	19.75 	3.81 
	TimelyFreeze+APF	mfr=0.8, th=0.01	32.43%	49.28%	38.14%	28.27%	37.03%	2.11%	69.53%	8416 	18.18 	19.38 	3.89 
	TimelyFreeze+AutoFreeze	mfr=0.8, p=80%	31.21%	49.22%	37.54%	26.81%	36.20%	1.27%	69.38%	8695 	22.10 	20.00 	3.77 
Interleaved 1F1B	No Freezing		30.44%	49.38%	38.40%	25.95%	36.04%	1.12%	0.00%	6815 	-	15.71 	4.81 
	APF	th=0.03	32.32%	48.21%	36.86%	24.60%	35.50%	0.57%	75.20%	8359 	22.66 	19.26 	3.92 
	AutoFreeze	p=80%	29.29%	48.76%	37.71%	26.07%	35.46%	0.53%	48.17%	7116 	4.42 	16.35 	4.60 
	TimelyFreeze	mfr=0.8	30.64%	48.41%	37.03%	25.95%	35.51%	0.58%	63.65%	8062 	18.29 	18.57 	4.06 
	TimelyFreeze+APF	mfr=0.8, th=0.03	31.42%	48.20%	37.12%	26.56%	35.83%	0.90%	62.10%	8167 	19.84 	18.78 	4.01 
	TimelyFreeze+AutoFreeze	mfr=0.8, p=80%	29.86%	48.43%	36.86%	25.70%	35.21%	0.29%	62.09%	8120 	19.16 	18.68 	4.04 

"""

latex_str = raw_to_latex_table(input_string,
	col_names=["pipeline", "method", "config", "mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	numeric_cols=["mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	columns=["pipeline","method","avg_acc","acc_gain","freeze","throughput","tp_gain","mfu"],
	datarow_cols=["avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu"],
	header=main_result_header(caption),
	footer=main_result_footer(label),
)
print(latex_str)
print(latex_str, file=open(output_file, "w"))
# Out:
# curr_pipe: None, r: {'pipeline': 'Base Pretrained Model', 'method': '', 'avg_acc': 34.93, 'acc_gain': '', 'freeze': '', 'throughput': '', 'tp_gain': '', 'mfu': ''}
# curr_pipe: Base Pretrained Model, r: {'pipeline': 'GPipe', 'method': 'No Freezing', 'avg_acc': 36.99, 'acc_gain': 2.06, 'freeze': 0.0, 'throughput': 7022.0, 'tp_gain': '', 'mfu': 16.2}
# curr_pipe: GPipe, r: {'pipeline': '1F1B', 'method': 'No Freezing', 'avg_acc': 36.59, 'acc_gain': 1.67, 'freeze': 0.0, 'throughput': 7121.0, 'tp_gain': '', 'mfu': 16.43}
# c: freeze values: dict_values([78.97, 60.37, 62.39, 60.91, 61.38]) best: 60.37 second_best: 60.91
# c: acc_gain values: dict_values([0.69, 0.71, 0.92, 0.75, 0.8]) best: 0.92 second_best: 0.8
# c: tp_gain values: dict_values([34.79, 8.03, 40.34, 41.21, 39.64]) best: 41.21 second_best: 40.34
# c: avg_acc values: dict_values([35.62, 35.63, 35.84, 35.68, 35.73]) best: 35.84 second_best: 35.73
# c: mfu values: dict_values([21.77, 17.45, 22.8, 22.9, 22.77]) best: 22.9 second_best: 22.8
# c: throughput values: dict_values([9466.0, 7586.0, 9855.0, 9916.0, 9806.0]) best: 9916.0 second_best: 9855.0
# pipe: GPipe, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 36.99 & 2.06 & 0 & 7022 & -- & 16.2 \\\\', '\\thincline{2-8}', ' & APF & 35.62 & 0.69 & 78.97 & 9466 & 34.79 & 21.77 \\\\', ' & AutoFreeze & 35.63 & 0.71 & \\textbf{60.37} & 7586 & 8.03 & 17.45 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{35.84} & \\cellcolor{gray!15}\\textbf{0.92} & \\cellcolor{gray!15}62.39 & \\cellcolor{gray!15}\\underline{9855} & \\cellcolor{gray!15}\\underline{40.34} & \\cellcolor{gray!15}\\underline{22.8} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}35.68 & \\cellcolor{lightgray!10}0.75 & \\cellcolor{lightgray!10}\\underline{60.91} & \\cellcolor{lightgray!10}\\textbf{9916} & \\cellcolor{lightgray!10}\\textbf{41.21} & \\cellcolor{lightgray!10}\\textbf{22.9} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\underline{35.73} & \\cellcolor{lightgray!10}\\underline{0.8} & \\cellcolor{lightgray!10}61.38 & \\cellcolor{lightgray!10}9806 & \\cellcolor{lightgray!10}39.64 & \\cellcolor{lightgray!10}22.77 \\\\']
# curr_pipe: 1F1B, r: {'pipeline': 'Interleaved 1F1B', 'method': 'No Freezing', 'avg_acc': 36.04, 'acc_gain': 1.12, 'freeze': 0.0, 'throughput': 6815.0, 'tp_gain': '', 'mfu': 15.71}
# c: freeze values: dict_values([68.89, 46.79, 69.3, 69.53, 69.38]) best: 46.79 second_best: 68.89
# c: acc_gain values: dict_values([0.94, 0.44, 1.79, 2.11, 1.27]) best: 2.11 second_best: 1.79
# c: tp_gain values: dict_values([12.4, 3.87, 20.66, 18.18, 22.1]) best: 22.1 second_best: 20.66
# c: avg_acc values: dict_values([35.86, 35.37, 36.71, 37.03, 36.2]) best: 37.03 second_best: 36.71
# c: mfu values: dict_values([18.43, 17.03, 19.75, 19.38, 20.0]) best: 20.0 second_best: 19.75
# c: throughput values: dict_values([8004.0, 7397.0, 8592.0, 8416.0, 8695.0]) best: 8695.0 second_best: 8592.0
# pipe: 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 36.59 & 1.67 & 0 & 7121 & -- & 16.43 \\\\', '\\thincline{2-8}', ' & APF & 35.86 & 0.94 & \\underline{68.89} & 8004 & 12.4 & 18.43 \\\\', ' & AutoFreeze & 35.37 & 0.44 & \\textbf{46.79} & 7397 & 3.87 & 17.03 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{36.71} & \\cellcolor{gray!15}\\underline{1.79} & \\cellcolor{gray!15}69.3 & \\cellcolor{gray!15}\\underline{8592} & \\cellcolor{gray!15}\\underline{20.66} & \\cellcolor{gray!15}\\underline{19.75} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\textbf{37.03} & \\cellcolor{lightgray!10}\\textbf{2.11} & \\cellcolor{lightgray!10}69.53 & \\cellcolor{lightgray!10}8416 & \\cellcolor{lightgray!10}18.18 & \\cellcolor{lightgray!10}19.38 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}36.2 & \\cellcolor{lightgray!10}1.27 & \\cellcolor{lightgray!10}69.38 & \\cellcolor{lightgray!10}\\textbf{8695} & \\cellcolor{lightgray!10}\\textbf{22.1} & \\cellcolor{lightgray!10}\\textbf{20} \\\\']
# c: freeze values: dict_values([75.2, 48.17, 63.65, 62.1, 62.09]) best: 48.17 second_best: 62.09
# c: acc_gain values: dict_values([0.57, 0.53, 0.58, 0.9, 0.29]) best: 0.9 second_best: 0.58
# c: tp_gain values: dict_values([22.66, 4.42, 18.29, 19.84, 19.16]) best: 22.66 second_best: 19.84
# c: avg_acc values: dict_values([35.5, 35.46, 35.51, 35.83, 35.21]) best: 35.83 second_best: 35.51
# c: mfu values: dict_values([19.26, 16.35, 18.57, 18.78, 18.68]) best: 19.26 second_best: 18.78
# c: throughput values: dict_values([8359.0, 7116.0, 8062.0, 8167.0, 8120.0]) best: 8359.0 second_best: 8167.0
# pipe: Interleaved 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 36.04 & 1.12 & 0 & 6815 & -- & 15.71 \\\\', '\\thincline{2-8}', ' & APF & 35.5 & 0.57 & 75.2 & \\textbf{8359} & \\textbf{22.66} & \\textbf{19.26} \\\\', ' & AutoFreeze & 35.46 & 0.53 & \\textbf{48.17} & 7116 & 4.42 & 16.35 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{35.51} & \\cellcolor{gray!15}\\underline{0.58} & \\cellcolor{gray!15}63.65 & \\cellcolor{gray!15}8062 & \\cellcolor{gray!15}18.29 & \\cellcolor{gray!15}18.57 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\textbf{35.83} & \\cellcolor{lightgray!10}\\textbf{0.9} & \\cellcolor{lightgray!10}62.1 & \\cellcolor{lightgray!10}\\underline{8167} & \\cellcolor{lightgray!10}\\underline{19.84} & \\cellcolor{lightgray!10}\\underline{18.78} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}35.21 & \\cellcolor{lightgray!10}0.29 & \\cellcolor{lightgray!10}\\underline{62.09} & \\cellcolor{lightgray!10}8120 & \\cellcolor{lightgray!10}19.16 & \\cellcolor{lightgray!10}18.68 \\\\']
# final latex:  ['\n\\begin{table*}[t]\n\\renewcommand{\\arraystretch}{1}\n\\centering\n\\caption{Comparison of freezing methods under different pipeline schedules (LLaMA-1B).}\n\\resizebox{\\textwidth}{!}{\n\\begin{tabular}{cl|ccc|ccc}\n\n%%%%% header %%%%%\n\\hline\n\\multirow{2}{*}{\\makecell[c]{Pipeline \\\\ Schedule}} &\n\\multicolumn{1}{c|}{\\multirow{2}{*}{\\makecell[c]{Freeze \\\\ Method}}} &\n\\multicolumn{3}{c|}{Accuracy Preservation} &\n\\multicolumn{3}{c}{Time Efficiency} \\\\\n\\cline{3-5} \\cline{6-8}\n& & Avg. Acc.↑ & Acc. Gain↑ & Freeze Ratio↓ & Throughput↑ & Th. Gain↑ & MFU↑ \\\\\n\n', '\\hline', '\\multicolumn{2}{c|}{Base Pretrained Model} & 34.93 & -- & -- & -- & -- & -- \\\\', '\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 36.99 & 2.06 & 0 & 7022 & -- & 16.2 \\\\\n\\thincline{2-8}\n & APF & 35.62 & 0.69 & 78.97 & 9466 & 34.79 & 21.77 \\\\\n & AutoFreeze & 35.63 & 0.71 & \\textbf{60.37} & 7586 & 8.03 & 17.45 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{35.84} & \\cellcolor{gray!15}\\textbf{0.92} & \\cellcolor{gray!15}62.39 & \\cellcolor{gray!15}\\underline{9855} & \\cellcolor{gray!15}\\underline{40.34} & \\cellcolor{gray!15}\\underline{22.8} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}35.68 & \\cellcolor{lightgray!10}0.75 & \\cellcolor{lightgray!10}\\underline{60.91} & \\cellcolor{lightgray!10}\\textbf{9916} & \\cellcolor{lightgray!10}\\textbf{41.21} & \\cellcolor{lightgray!10}\\textbf{22.9} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\underline{35.73} & \\cellcolor{lightgray!10}\\underline{0.8} & \\cellcolor{lightgray!10}61.38 & \\cellcolor{lightgray!10}9806 & \\cellcolor{lightgray!10}39.64 & \\cellcolor{lightgray!10}22.77 \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 36.59 & 1.67 & 0 & 7121 & -- & 16.43 \\\\\n\\thincline{2-8}\n & APF & 35.86 & 0.94 & \\underline{68.89} & 8004 & 12.4 & 18.43 \\\\\n & AutoFreeze & 35.37 & 0.44 & \\textbf{46.79} & 7397 & 3.87 & 17.03 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{36.71} & \\cellcolor{gray!15}\\underline{1.79} & \\cellcolor{gray!15}69.3 & \\cellcolor{gray!15}\\underline{8592} & \\cellcolor{gray!15}\\underline{20.66} & \\cellcolor{gray!15}\\underline{19.75} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\textbf{37.03} & \\cellcolor{lightgray!10}\\textbf{2.11} & \\cellcolor{lightgray!10}69.53 & \\cellcolor{lightgray!10}8416 & \\cellcolor{lightgray!10}18.18 & \\cellcolor{lightgray!10}19.38 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}36.2 & \\cellcolor{lightgray!10}1.27 & \\cellcolor{lightgray!10}69.38 & \\cellcolor{lightgray!10}\\textbf{8695} & \\cellcolor{lightgray!10}\\textbf{22.1} & \\cellcolor{lightgray!10}\\textbf{20} \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 36.04 & 1.12 & 0 & 6815 & -- & 15.71 \\\\\n\\thincline{2-8}\n & APF & 35.5 & 0.57 & 75.2 & \\textbf{8359} & \\textbf{22.66} & \\textbf{19.26} \\\\\n & AutoFreeze & 35.46 & 0.53 & \\textbf{48.17} & 7116 & 4.42 & 16.35 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{35.51} & \\cellcolor{gray!15}\\underline{0.58} & \\cellcolor{gray!15}63.65 & \\cellcolor{gray!15}8062 & \\cellcolor{gray!15}18.29 & \\ ...
#
# \begin{table*}[t]
# \renewcommand{\arraystretch}{1}
# \centering
# \caption{Comparison of freezing methods under different pipeline schedules (LLaMA-1B).}
# \resizebox{\textwidth}{!}{
# \begin{tabular}{cl|ccc|ccc}
#
# %%%%% header %%%%%
# \hline
# \multirow{2}{*}{\makecell[c]{Pipeline \\ Schedule}} &
# \multicolumn{1}{c|}{\multirow{2}{*}{\makecell[c]{Freeze \\ Method}}} &
# \multicolumn{3}{c|}{Accuracy Preservation} &
# \multicolumn{3}{c}{Time Efficiency} \\
# \cline{3-5} \cline{6-8}
# & & Avg. Acc.↑ & Acc. Gain↑ & Freeze Ratio↓ & Throughput↑ & Th. Gain↑ & MFU↑ \\
#
#
# \hline
# \multicolumn{2}{c|}{Base Pretrained Model} & 34.93 & -- & -- & -- & -- & -- \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{GPipe}} & No Freezing & 36.99 & 2.06 & 0 & 7022 & -- & 16.2 \\
# \thincline{2-8}
#  & APF & 35.62 & 0.69 & 78.97 & 9466 & 34.79 & 21.77 \\
#  & AutoFreeze & 35.63 & 0.71 & \textbf{60.37} & 7586 & 8.03 & 17.45 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\textbf{35.84} & \cellcolor{gray!15}\textbf{0.92} & \cellcolor{gray!15}62.39 & \cellcolor{gray!15}\underline{9855} & \cellcolor{gray!15}\underline{40.34} & \cellcolor{gray!15}\underline{22.8} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}35.68 & \cellcolor{lightgray!10}0.75 & \cellcolor{lightgray!10}\underline{60.91} & \cellcolor{lightgray!10}\textbf{9916} & \cellcolor{lightgray!10}\textbf{41.21} & \cellcolor{lightgray!10}\textbf{22.9} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}\underline{35.73} & \cellcolor{lightgray!10}\underline{0.8} & \cellcolor{lightgray!10}61.38 & \cellcolor{lightgray!10}9806 & \cellcolor{lightgray!10}39.64 & \cellcolor{lightgray!10}22.77 \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{1F1B}} & No Freezing & 36.59 & 1.67 & 0 & 7121 & -- & 16.43 \\
# \thincline{2-8}
#  & APF & 35.86 & 0.94 & \underline{68.89} & 8004 & 12.4 & 18.43 \\
#  & AutoFreeze & 35.37 & 0.44 & \textbf{46.79} & 7397 & 3.87 & 17.03 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\underline{36.71} & \cellcolor{gray!15}\underline{1.79} & \cellcolor{gray!15}69.3 & \cellcolor{gray!15}\underline{8592} & \cellcolor{gray!15}\underline{20.66} & \cellcolor{gray!15}\underline{19.75} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\textbf{37.03} & \cellcolor{lightgray!10}\textbf{2.11} & \cellcolor{lightgray!10}69.53 & \cellcolor{lightgray!10}8416 & \cellcolor{lightgray!10}18.18 & \cellcolor{lightgray!10}19.38 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}36.2 & \cellcolor{lightgray!10}1.27 & \cellcolor{lightgray!10}69.38 & \cellcolor{lightgray!10}\textbf{8695} & \cellcolor{lightgray!10}\textbf{22.1} & \cellcolor{lightgray!10}\textbf{20} \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{Interleaved\\1F1B}} & No Freezing & 36.04 & 1.12 & 0 & 6815 & -- & 15.71 \\
# \thincline{2-8}
#  & APF & 35.5 & 0.57 & 75.2 & \textbf{8359} & \textbf{22.66} & \textbf{19.26} \\
#  & AutoFreeze & 35.46 & 0.53 & \textbf{48.17} & 7116 & 4.42 & 16.35 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\underline{35.51} & \cellcolor{gray!15}\underline{0.58} & \cellcolor{gray!15}63.65 & \cellcolor{gray!15}8062 & \cellcolor{gray!15}18.29 & \cellcolor{gray!15}18.57 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\textbf{35.83} & \cellcolor{lightgray!10}\textbf{0.9} & \cellcolor{lightgray!10}62.1 & \cellcolor{lightgray!10}\underline{8167} & \cellcolor{lightgray!10}\underline{19.84} & \cellcolor{lightgray!10}\underline{18.78} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}35.21 & \cellcolor{lightgray!10}0.29 & \cellcolor{lightgray!10}\underline{62.09} & \cellcolor{lightgray!10}8120 & \cellcolor{lightgray!10}19.16 & \cellcolor{lightgray!10}18.68 \\
# \hline
#
#
# \end{tabular}}
# \label{tab:llama1b}
# \end{table*}

# %% [markdown]
# ## 1B Benchmark

# %%
def benchmark_header(caption:str="Some Fancy Caption.") -> str:
    return r"""
\begin{table*}[t]
\renewcommand{\arraystretch}{1}
\centering
\caption{""" + caption + r"""}\resizebox{0.85\linewidth}{!}{
\begin{tabular}{cl|cccc|c}

%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%% Header %%%%%%%%%%%%%%%%%%%%%%%%%%%
%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
\hline
\multirow{3}{*}{\makecell[c]{Pipeline \\Schedule }} &
\multicolumn{1}{c|}{\multirow{3}{*}{\makecell[c]{Freeze \\Method }}} &
\multicolumn{4}{c|}{Benchmark Scores (\%) ↑} &
\multirow{3}{*}{\makecell[c]{Average \\Accuracy↑ }} \\
\cline{3-6}
& & \makecell[c]{MMLU\\[-5pt]\scriptsize{(5 shots)}} &
\makecell[c]{HellaSwag\\[-5pt]\scriptsize{(0 shots)}} &
\makecell[c]{ARC-C\\[-5pt]\scriptsize{(10 shots)}} &
\makecell[c]{TruthfulQA\\[-5pt]\scriptsize{(0 shots)}} \\

"""

def benchmark_footer(label:str="some_fancy_label") -> str:
    return r"""
\end{tabular}}
\label{tab:""" + label.replace(" ", "_") + r"""}
\end{table*}
"""

# %%
# Benchmark score
caption = "Detailed Benchmark Scores under different pipeline schedules (LLaMA-1B)."
label = "llama1b_benchmark"
output_file = label + "_table.txt"


latex_str = raw_to_latex_table(input_string,
	col_names=["pipeline", "method", "config", "mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	numeric_cols=["mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	columns=["pipeline","method","mmlu","hella","arc","tqa","avg_acc"],
	datarow_cols=["mmlu", "hella", "arc", "tqa", "avg_acc"],
	header=benchmark_header(caption),
	footer=benchmark_footer(label),
)
print(latex_str)
print(latex_str, file=open(output_file, "w"))
# Out:
# curr_pipe: None, r: {'pipeline': 'Base Pretrained Model', 'method': '', 'mmlu': 31.99, 'hella': 47.75, 'arc': 36.95, 'tqa': 23.01, 'avg_acc': 34.93}
# curr_pipe: Base Pretrained Model, r: {'pipeline': 'GPipe', 'method': 'No Freezing', 'mmlu': 32.54, 'hella': 49.28, 'arc': 37.37, 'tqa': 28.76, 'avg_acc': 36.99}
# curr_pipe: GPipe, r: {'pipeline': '1F1B', 'method': 'No Freezing', 'mmlu': 31.23, 'hella': 49.88, 'arc': 37.71, 'tqa': 27.54, 'avg_acc': 36.59}
# c: arc values: dict_values([37.2, 36.69, 36.86, 37.12, 37.12]) best: 37.2 second_best: 37.12
# c: hella values: dict_values([48.27, 48.32, 48.22, 48.16, 48.14]) best: 48.32 second_best: 48.27
# c: mmlu values: dict_values([32.27, 30.96, 32.46, 32.33, 32.07]) best: 32.46 second_best: 32.33
# c: avg_acc values: dict_values([35.62, 35.63, 35.84, 35.68, 35.73]) best: 35.84 second_best: 35.73
# c: tqa values: dict_values([24.72, 26.56, 25.83, 25.09, 25.58]) best: 26.56 second_best: 25.83
# pipe: GPipe, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 32.54 & 49.28 & 37.37 & 28.76 & 36.99 \\\\', '\\thincline{2-7}', ' & APF & 32.27 & \\underline{48.27} & \\textbf{37.2} & 24.72 & 35.62 \\\\', ' & AutoFreeze & 30.96 & \\textbf{48.32} & 36.69 & \\textbf{26.56} & 35.63 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{32.46} & \\cellcolor{gray!15}48.22 & \\cellcolor{gray!15}36.86 & \\cellcolor{gray!15}\\underline{25.83} & \\cellcolor{gray!15}\\textbf{35.84} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{32.33} & \\cellcolor{lightgray!10}48.16 & \\cellcolor{lightgray!10}\\underline{37.12} & \\cellcolor{lightgray!10}25.09 & \\cellcolor{lightgray!10}35.68 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}32.07 & \\cellcolor{lightgray!10}48.14 & \\cellcolor{lightgray!10}\\underline{37.12} & \\cellcolor{lightgray!10}25.58 & \\cellcolor{lightgray!10}\\underline{35.73} \\\\']
# curr_pipe: 1F1B, r: {'pipeline': 'Interleaved 1F1B', 'method': 'No Freezing', 'mmlu': 30.44, 'hella': 49.38, 'arc': 38.4, 'tqa': 25.95, 'avg_acc': 36.04}
# c: arc values: dict_values([37.03, 37.63, 37.97, 38.14, 37.54]) best: 38.14 second_best: 37.97
# c: hella values: dict_values([48.37, 47.8, 49.06, 49.28, 49.22]) best: 49.28 second_best: 49.22
# c: mmlu values: dict_values([32.59, 30.69, 32.27, 32.43, 31.21]) best: 32.59 second_best: 32.43
# c: avg_acc values: dict_values([35.86, 35.37, 36.71, 37.03, 36.2]) best: 37.03 second_best: 36.71
# c: tqa values: dict_values([25.46, 25.34, 27.54, 28.27, 26.81]) best: 28.27 second_best: 27.54
# pipe: 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 31.23 & 49.88 & 37.71 & 27.54 & 36.59 \\\\', '\\thincline{2-7}', ' & APF & \\textbf{32.59} & 48.37 & 37.03 & 25.46 & 35.86 \\\\', ' & AutoFreeze & 30.69 & 47.8 & 37.63 & 25.34 & 35.37 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}32.27 & \\cellcolor{gray!15}49.06 & \\cellcolor{gray!15}\\underline{37.97} & \\cellcolor{gray!15}\\underline{27.54} & \\cellcolor{gray!15}\\underline{36.71} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{32.43} & \\cellcolor{lightgray!10}\\textbf{49.28} & \\cellcolor{lightgray!10}\\textbf{38.14} & \\cellcolor{lightgray!10}\\textbf{28.27} & \\cellcolor{lightgray!10}\\textbf{37.03} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}31.21 & \\cellcolor{lightgray!10}\\underline{49.22} & \\cellcolor{lightgray!10}37.54 & \\cellcolor{lightgray!10}26.81 & \\cellcolor{lightgray!10}36.2 \\\\']
# c: arc values: dict_values([36.86, 37.71, 37.03, 37.12, 36.86]) best: 37.71 second_best: 37.12
# c: hella values: dict_values([48.21, 48.76, 48.41, 48.2, 48.43]) best: 48.76 second_best: 48.43
# c: mmlu values: dict_values([32.32, 29.29, 30.64, 31.42, 29.86]) best: 32.32 second_best: 31.42
# c: avg_acc values: dict_values([35.5, 35.46, 35.51, 35.83, 35.21]) best: 35.83 second_best: 35.51
# c: tqa values: dict_values([24.6, 26.07, 25.95, 26.56, 25.7]) best: 26.56 second_best: 26.07
# pipe: Interleaved 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 30.44 & 49.38 & 38.4 & 25.95 & 36.04 \\\\', '\\thincline{2-7}', ' & APF & \\textbf{32.32} & 48.21 & 36.86 & 24.6 & 35.5 \\\\', ' & AutoFreeze & 29.29 & \\textbf{48.76} & \\textbf{37.71} & \\underline{26.07} & 35.46 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}30.64 & \\cellcolor{gray!15}48.41 & \\cellcolor{gray!15}37.03 & \\cellcolor{gray!15}25.95 & \\cellcolor{gray!15}\\underline{35.51} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{31.42} & \\cellcolor{lightgray!10}48.2 & \\cellcolor{lightgray!10}\\underline{37.12} & \\cellcolor{lightgray!10}\\textbf{26.56} & \\cellcolor{lightgray!10}\\textbf{35.83} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}29.86 & \\cellcolor{lightgray!10}\\underline{48.43} & \\cellcolor{lightgray!10}36.86 & \\cellcolor{lightgray!10}25.7 & \\cellcolor{lightgray!10}35.21 \\\\']
# final latex:  ['\n\\begin{table*}[t]\n\\renewcommand{\\arraystretch}{1}\n\\centering\n\\caption{Detailed Benchmark Scores under different pipeline schedules (LLaMA-1B).}\\resizebox{0.85\\linewidth}{!}{\n\\begin{tabular}{cl|cccc|c}\n\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%% Header %%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\hline\n\\multirow{3}{*}{\\makecell[c]{Pipeline \\\\Schedule }} &\n\\multicolumn{1}{c|}{\\multirow{3}{*}{\\makecell[c]{Freeze \\\\Method }}} &\n\\multicolumn{4}{c|}{Benchmark Scores (\\%) ↑} &\n\\multirow{3}{*}{\\makecell[c]{Average \\\\Accuracy↑ }} \\\\\n\\cline{3-6}\n& & \\makecell[c]{MMLU\\\\[-5pt]\\scriptsize{(5 shots)}} &\n\\makecell[c]{HellaSwag\\\\[-5pt]\\scriptsize{(0 shots)}} &\n\\makecell[c]{ARC-C\\\\[-5pt]\\scriptsize{(10 shots)}} &\n\\makecell[c]{TruthfulQA\\\\[-5pt]\\scriptsize{(0 shots)}} \\\\\n\n', '\\hline', '\\multicolumn{2}{c|}{Base Pretrained Model} & 31.99 & 47.75 & 36.95 & 23.01 & 34.93 \\\\', '\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 32.54 & 49.28 & 37.37 & 28.76 & 36.99 \\\\\n\\thincline{2-7}\n & APF & 32.27 & \\underline{48.27} & \\textbf{37.2} & 24.72 & 35.62 \\\\\n & AutoFreeze & 30.96 & \\textbf{48.32} & 36.69 & \\textbf{26.56} & 35.63 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{32.46} & \\cellcolor{gray!15}48.22 & \\cellcolor{gray!15}36.86 & \\cellcolor{gray!15}\\underline{25.83} & \\cellcolor{gray!15}\\textbf{35.84} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{32.33} & \\cellcolor{lightgray!10}48.16 & \\cellcolor{lightgray!10}\\underline{37.12} & \\cellcolor{lightgray!10}25.09 & \\cellcolor{lightgray!10}35.68 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}32.07 & \\cellcolor{lightgray!10}48.14 & \\cellcolor{lightgray!10}\\underline{37.12} & \\cellcolor{lightgray!10}25.58 & \\cellcolor{lightgray!10}\\underline{35.73} \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 31.23 & 49.88 & 37.71 & 27.54 & 36.59 \\\\\n\\thincline{2-7}\n & APF & \\textbf{32.59} & 48.37 & 37.03 & 25.46 & 35.86 \\\\\n & AutoFreeze & 30.69 & 47.8 & 37.63 & 25.34 & 35.37 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}32.27 & \\cellcolor{gray!15}49.06 & \\cellcolor{gray!15}\\underline{37.97} & \\cellcolor{gray!15}\\underline{27.54} & \\cellcolor{gray!15}\\underline{36.71} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{32.43} & \\cellcolor{lightgray!10}\\textbf{49.28} & \\cellcolor{lightgray!10}\\textbf{38.14} & \\cellcolor{lightgray!10}\\textbf{28.27} & \\cellcolor{lightgray!10}\\textbf{37.03} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}31.21 & \\cellcolor{lightgray!10}\\underline{49.22} & \\cellcolor{lightgray!10}37.54 & \\cellcolor{lightgray!10}26.81 & \\cellcolor{lightgray!10}36.2 \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 30.44 & 49.38 & 38.4 & 25.95 & 36.04 \\\\\n\\thincline{2-7}\n & APF & \\textbf{32.32} & 48.21 & 36.86 & 24.6 & 35.5 \\\\\n & AutoFreeze & 29.29 & \\textbf{48.76} & \\textbf{37.71} & \\underline{26.07} & 35.46 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}30.64 & \\cellcolor{gray!15}48.41 ...
#
# \begin{table*}[t]
# \renewcommand{\arraystretch}{1}
# \centering
# \caption{Detailed Benchmark Scores under different pipeline schedules (LLaMA-1B).}\resizebox{0.85\linewidth}{!}{
# \begin{tabular}{cl|cccc|c}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%% Header %%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \hline
# \multirow{3}{*}{\makecell[c]{Pipeline \\Schedule }} &
# \multicolumn{1}{c|}{\multirow{3}{*}{\makecell[c]{Freeze \\Method }}} &
# \multicolumn{4}{c|}{Benchmark Scores (\%) ↑} &
# \multirow{3}{*}{\makecell[c]{Average \\Accuracy↑ }} \\
# \cline{3-6}
# & & \makecell[c]{MMLU\\[-5pt]\scriptsize{(5 shots)}} &
# \makecell[c]{HellaSwag\\[-5pt]\scriptsize{(0 shots)}} &
# \makecell[c]{ARC-C\\[-5pt]\scriptsize{(10 shots)}} &
# \makecell[c]{TruthfulQA\\[-5pt]\scriptsize{(0 shots)}} \\
#
#
# \hline
# \multicolumn{2}{c|}{Base Pretrained Model} & 31.99 & 47.75 & 36.95 & 23.01 & 34.93 \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{GPipe}} & No Freezing & 32.54 & 49.28 & 37.37 & 28.76 & 36.99 \\
# \thincline{2-7}
#  & APF & 32.27 & \underline{48.27} & \textbf{37.2} & 24.72 & 35.62 \\
#  & AutoFreeze & 30.96 & \textbf{48.32} & 36.69 & \textbf{26.56} & 35.63 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\textbf{32.46} & \cellcolor{gray!15}48.22 & \cellcolor{gray!15}36.86 & \cellcolor{gray!15}\underline{25.83} & \cellcolor{gray!15}\textbf{35.84} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\underline{32.33} & \cellcolor{lightgray!10}48.16 & \cellcolor{lightgray!10}\underline{37.12} & \cellcolor{lightgray!10}25.09 & \cellcolor{lightgray!10}35.68 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}32.07 & \cellcolor{lightgray!10}48.14 & \cellcolor{lightgray!10}\underline{37.12} & \cellcolor{lightgray!10}25.58 & \cellcolor{lightgray!10}\underline{35.73} \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{1F1B}} & No Freezing & 31.23 & 49.88 & 37.71 & 27.54 & 36.59 \\
# \thincline{2-7}
#  & APF & \textbf{32.59} & 48.37 & 37.03 & 25.46 & 35.86 \\
#  & AutoFreeze & 30.69 & 47.8 & 37.63 & 25.34 & 35.37 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}32.27 & \cellcolor{gray!15}49.06 & \cellcolor{gray!15}\underline{37.97} & \cellcolor{gray!15}\underline{27.54} & \cellcolor{gray!15}\underline{36.71} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\underline{32.43} & \cellcolor{lightgray!10}\textbf{49.28} & \cellcolor{lightgray!10}\textbf{38.14} & \cellcolor{lightgray!10}\textbf{28.27} & \cellcolor{lightgray!10}\textbf{37.03} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}31.21 & \cellcolor{lightgray!10}\underline{49.22} & \cellcolor{lightgray!10}37.54 & \cellcolor{lightgray!10}26.81 & \cellcolor{lightgray!10}36.2 \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{Interleaved\\1F1B}} & No Freezing & 30.44 & 49.38 & 38.4 & 25.95 & 36.04 \\
# \thincline{2-7}
#  & APF & \textbf{32.32} & 48.21 & 36.86 & 24.6 & 35.5 \\
#  & AutoFreeze & 29.29 & \textbf{48.76} & \textbf{37.71} & \underline{26.07} & 35.46 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}30.64 & \cellcolor{gray!15}48.41 & \cellcolor{gray!15}37.03 & \cellcolor{gray!15}25.95 & \cellcolor{gray!15}\underline{35.51} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\underline{31.42} & \cellcolor{lightgray!10}48.2 & \cellcolor{lightgray!10}\underline{37.12} & \cellcolor{lightgray!10}\textbf{26.56} & \cellcolor{lightgray!10}\textbf{35.83} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}29.86 & \cellcolor{lightgray!10}\underline{48.43} & \cellcolor{lightgray!10}36.86 & \cellcolor{lightgray!10}25.7 & \cellcolor{lightgray!10}35.21 \\
# \hline
#
#
# \end{tabular}}
# \label{tab:llama1b_benchmark}
# \end{table*}

# %%
caption = "Comparison of freezing methods under different pipeline schedules (LLaMA-8B)."
label = "llama8b"
output_file = label + "_table.txt"

input_string = """
"Pipeline 
Schedule"	Freeze Method		Accuracy Preservation							Time Efficiency			
			"MMLU
(5 shots)
 ↑"	"HellaSwag
 ↑"	"ARC challenge
 ↑"	"TruthfulQA
 ↑"	"Average
Acc.↑"	"Accuracy
Gain (%) ↑"	"Avg. Freeze 
Ratio (%) ↓"	"Avg. 
Throughput 
(token/s) ↑"	"Throughput
Gain (%) ↑"	Avg. mfu (%) ↑	"Avg. Batch
Time (s) ↓"
Base Pretrained Model			63.55%	60.00%	51.28%	28.40%	50.81%		-				
GPipe	No Freezing		64.24%	60.43%	56.06%	39.05%	54.95%	4.14%	0.00%	6261 	-	28.30 	2.62 
	APF	th=0.005	63.69%	61.34%	55.12%	37.82%	54.49%	3.69%	70.53%	8360 	33.51 	38.13 	1.96 
	AutoFreeze	p=80%	64.61%	60.86%	54.86%	37.82%	54.54%	3.73%	81.95%	8052 	28.59 	36.72 	2.03 
	TimelyFreeze	mfr=0.7	63.93%	61.06%	54.44%	36.47%	53.98%	3.17%	38.84%	7412 	18.37 	33.58 	2.21 
	TimelyFreeze+APF	mfr=0.7, th=0.005	64.10%	61.00%	53.67%	37.58%	54.09%	3.28%	39.19%	7432 	18.69 	33.67 	2.20 
	TimelyFreeze+AutoFreeze	mfr=0.7, p=80%	64.20%	61.04%	54.01%	37.58%	54.21%	3.40%	43.27%	8440 	34.80 	38.49 	1.94 
1F1B	No Freezing		64.15%	60.49%	55.55%	39.05%	54.81%	4.00%	0.00%	6262 	-	28.31 	2.62 
	APF	th=0.003	64.25%	61.27%	54.78%	36.47%	54.19%	3.39%	69.92%	8344 	33.24 	38.04 	1.96 
	AutoFreeze	p=80%	64.18%	60.70%	54.10%	37.58%	54.14%	3.33%	78.02%	7925 	26.54 	36.14 	2.07 
	TimelyFreeze	mfr=0.7	64.54%	60.56%	55.72%	39.90%	55.18%	4.37%	38.63%	8133 	29.87 	37.00 	2.01 
	TimelyFreeze+APF	mfr=0.7, th=0.003	64.29%	60.91%	55.20%	40.51%	55.23%	4.42%	37.69%	8201 	30.95 	37.31 	2.00 
	TimelyFreeze+AutoFreeze	mfr=0.7, p=80%	64.37%	60.83%	54.44%	37.33%	54.24%	3.44%	38.36%	8213 	31.14 	37.39 	1.99 
Interleaved 1F1B	No Freezing		64.38%	60.35%	55.63%	38.92%	54.82%	4.01%	0.00%	6088 	-	27.92 	2.69 
	APF	th=0.05	64.04%	61.17%	54.86%	36.35%	54.11%	3.30%	74.88%	8350 	37.15 	38.16 	1.96 
	AutoFreeze	p=80%	64.24%	61.00%	54.18%	35.74%	53.79%	2.98%	79.33%	7494 	23.09 	34.54 	2.19 
	TimelyFreeze	mfr=0.7	64.61%	60.90%	54.61%	36.60%	54.18%	3.37%	45.69%	7796 	28.05 	35.89 	2.10 
	TimelyFreeze+APF	mfr=0.7, th=0.01	64.71%	60.91%	54.44%	37.33%	54.35%	3.54%	44.30%	7738 	27.09 	35.16 	2.12 
	TimelyFreeze+AutoFreeze	mfr=0.7, p=80%	64.91%	60.98%	54.10%	37.33%	54.33%	3.52%	44.66%	7797 	28.07 	35.44 	2.10 

"""

latex_str = raw_to_latex_table(input_string,
	col_names=["pipeline", "method", "config", "mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	numeric_cols=["mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	columns=["pipeline","method","avg_acc","acc_gain","freeze","throughput","tp_gain","mfu"],
	header=main_result_header(caption),
	footer=main_result_footer(label),
)
print(latex_str)
print(latex_str, file=open(output_file, "w"))
# Out:
# curr_pipe: None, r: {'pipeline': 'Base Pretrained Model', 'method': '', 'avg_acc': 50.81, 'acc_gain': '', 'freeze': '', 'throughput': '', 'tp_gain': '', 'mfu': ''}
# curr_pipe: Base Pretrained Model, r: {'pipeline': 'GPipe', 'method': 'No Freezing', 'avg_acc': 54.95, 'acc_gain': 4.14, 'freeze': 0.0, 'throughput': 6261.0, 'tp_gain': '', 'mfu': 28.3}
# curr_pipe: GPipe, r: {'pipeline': '1F1B', 'method': 'No Freezing', 'avg_acc': 54.81, 'acc_gain': 4.0, 'freeze': 0.0, 'throughput': 6262.0, 'tp_gain': '', 'mfu': 28.31}
# c: freeze values: dict_values([70.53, 81.95, 38.84, 39.19, 43.27]) best: 38.84 second_best: 39.19
# c: acc_gain values: dict_values([3.69, 3.73, 3.17, 3.28, 3.4]) best: 3.73 second_best: 3.69
# c: tp_gain values: dict_values([33.51, 28.59, 18.37, 18.69, 34.8]) best: 34.8 second_best: 33.51
# c: avg_acc values: dict_values([54.49, 54.54, 53.98, 54.09, 54.21]) best: 54.54 second_best: 54.49
# c: mfu values: dict_values([38.13, 36.72, 33.58, 33.67, 38.49]) best: 38.49 second_best: 38.13
# c: throughput values: dict_values([8360.0, 8052.0, 7412.0, 7432.0, 8440.0]) best: 8440.0 second_best: 8360.0
# pipe: GPipe, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 54.95 & 4.14 & 0 & 6261 & -- & 28.3 \\\\', '\\thincline{2-8}', ' & APF & \\underline{54.49} & \\underline{3.69} & 70.53 & \\underline{8360} & \\underline{33.51} & \\underline{38.13} \\\\', ' & AutoFreeze & \\textbf{54.54} & \\textbf{3.73} & 81.95 & 8052 & 28.59 & 36.72 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}53.98 & \\cellcolor{gray!15}3.17 & \\cellcolor{gray!15}\\textbf{38.84} & \\cellcolor{gray!15}7412 & \\cellcolor{gray!15}18.37 & \\cellcolor{gray!15}33.58 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}54.09 & \\cellcolor{lightgray!10}3.28 & \\cellcolor{lightgray!10}\\underline{39.19} & \\cellcolor{lightgray!10}7432 & \\cellcolor{lightgray!10}18.69 & \\cellcolor{lightgray!10}33.67 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}54.21 & \\cellcolor{lightgray!10}3.4 & \\cellcolor{lightgray!10}43.27 & \\cellcolor{lightgray!10}\\textbf{8440} & \\cellcolor{lightgray!10}\\textbf{34.8} & \\cellcolor{lightgray!10}\\textbf{38.49} \\\\']
# curr_pipe: 1F1B, r: {'pipeline': 'Interleaved 1F1B', 'method': 'No Freezing', 'avg_acc': 54.82, 'acc_gain': 4.01, 'freeze': 0.0, 'throughput': 6088.0, 'tp_gain': '', 'mfu': 27.92}
# c: freeze values: dict_values([69.92, 78.02, 38.63, 37.69, 38.36]) best: 37.69 second_best: 38.36
# c: acc_gain values: dict_values([3.39, 3.33, 4.37, 4.42, 3.44]) best: 4.42 second_best: 4.37
# c: tp_gain values: dict_values([33.24, 26.54, 29.87, 30.95, 31.14]) best: 33.24 second_best: 31.14
# c: avg_acc values: dict_values([54.19, 54.14, 55.18, 55.23, 54.24]) best: 55.23 second_best: 55.18
# c: mfu values: dict_values([38.04, 36.14, 37.0, 37.31, 37.39]) best: 38.04 second_best: 37.39
# c: throughput values: dict_values([8344.0, 7925.0, 8133.0, 8201.0, 8213.0]) best: 8344.0 second_best: 8213.0
# pipe: 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 54.81 & 4 & 0 & 6262 & -- & 28.31 \\\\', '\\thincline{2-8}', ' & APF & 54.19 & 3.39 & 69.92 & \\textbf{8344} & \\textbf{33.24} & \\textbf{38.04} \\\\', ' & AutoFreeze & 54.14 & 3.33 & 78.02 & 7925 & 26.54 & 36.14 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{55.18} & \\cellcolor{gray!15}\\underline{4.37} & \\cellcolor{gray!15}38.63 & \\cellcolor{gray!15}8133 & \\cellcolor{gray!15}29.87 & \\cellcolor{gray!15}37 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\textbf{55.23} & \\cellcolor{lightgray!10}\\textbf{4.42} & \\cellcolor{lightgray!10}\\textbf{37.69} & \\cellcolor{lightgray!10}8201 & \\cellcolor{lightgray!10}30.95 & \\cellcolor{lightgray!10}37.31 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}54.24 & \\cellcolor{lightgray!10}3.44 & \\cellcolor{lightgray!10}\\underline{38.36} & \\cellcolor{lightgray!10}\\underline{8213} & \\cellcolor{lightgray!10}\\underline{31.14} & \\cellcolor{lightgray!10}\\underline{37.39} \\\\']
# c: freeze values: dict_values([74.88, 79.33, 45.69, 44.3, 44.66]) best: 44.3 second_best: 44.66
# c: acc_gain values: dict_values([3.3, 2.98, 3.37, 3.54, 3.52]) best: 3.54 second_best: 3.52
# c: tp_gain values: dict_values([37.15, 23.09, 28.05, 27.09, 28.07]) best: 37.15 second_best: 28.07
# c: avg_acc values: dict_values([54.11, 53.79, 54.18, 54.35, 54.33]) best: 54.35 second_best: 54.33
# c: mfu values: dict_values([38.16, 34.54, 35.89, 35.16, 35.44]) best: 38.16 second_best: 35.89
# c: throughput values: dict_values([8350.0, 7494.0, 7796.0, 7738.0, 7797.0]) best: 8350.0 second_best: 7797.0
# pipe: Interleaved 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 54.82 & 4.01 & 0 & 6088 & -- & 27.92 \\\\', '\\thincline{2-8}', ' & APF & 54.11 & 3.3 & 74.88 & \\textbf{8350} & \\textbf{37.15} & \\textbf{38.16} \\\\', ' & AutoFreeze & 53.79 & 2.98 & 79.33 & 7494 & 23.09 & 34.54 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}54.18 & \\cellcolor{gray!15}3.37 & \\cellcolor{gray!15}45.69 & \\cellcolor{gray!15}7796 & \\cellcolor{gray!15}28.05 & \\cellcolor{gray!15}\\underline{35.89} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\textbf{54.35} & \\cellcolor{lightgray!10}\\textbf{3.54} & \\cellcolor{lightgray!10}\\textbf{44.3} & \\cellcolor{lightgray!10}7738 & \\cellcolor{lightgray!10}27.09 & \\cellcolor{lightgray!10}35.16 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\underline{54.33} & \\cellcolor{lightgray!10}\\underline{3.52} & \\cellcolor{lightgray!10}\\underline{44.66} & \\cellcolor{lightgray!10}\\underline{7797} & \\cellcolor{lightgray!10}\\underline{28.07} & \\cellcolor{lightgray!10}35.44 \\\\']
# final latex:  ['\n\\begin{table*}[t]\n\\renewcommand{\\arraystretch}{1}\n\\centering\n\\caption{Comparison of freezing methods under different pipeline schedules (LLaMA-8B).}\n\\resizebox{\\textwidth}{!}{\n\\begin{tabular}{cl|ccc|ccc}\n\n%%%%% header %%%%%\n\\hline\n\\multirow{2}{*}{\\makecell[c]{Pipeline \\\\ Schedule}} &\n\\multicolumn{1}{c|}{\\multirow{2}{*}{\\makecell[c]{Freeze \\\\ Method}}} &\n\\multicolumn{3}{c|}{Accuracy Preservation} &\n\\multicolumn{3}{c}{Time Efficiency} \\\\\n\\cline{3-5} \\cline{6-8}\n& & Avg. Acc.↑ & Acc. Gain↑ & Freeze Ratio↓ & Throughput↑ & Th. Gain↑ & MFU↑ \\\\\n\n', '\\hline', '\\multicolumn{2}{c|}{Base Pretrained Model} & 50.81 & -- & -- & -- & -- & -- \\\\', '\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 54.95 & 4.14 & 0 & 6261 & -- & 28.3 \\\\\n\\thincline{2-8}\n & APF & \\underline{54.49} & \\underline{3.69} & 70.53 & \\underline{8360} & \\underline{33.51} & \\underline{38.13} \\\\\n & AutoFreeze & \\textbf{54.54} & \\textbf{3.73} & 81.95 & 8052 & 28.59 & 36.72 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}53.98 & \\cellcolor{gray!15}3.17 & \\cellcolor{gray!15}\\textbf{38.84} & \\cellcolor{gray!15}7412 & \\cellcolor{gray!15}18.37 & \\cellcolor{gray!15}33.58 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}54.09 & \\cellcolor{lightgray!10}3.28 & \\cellcolor{lightgray!10}\\underline{39.19} & \\cellcolor{lightgray!10}7432 & \\cellcolor{lightgray!10}18.69 & \\cellcolor{lightgray!10}33.67 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}54.21 & \\cellcolor{lightgray!10}3.4 & \\cellcolor{lightgray!10}43.27 & \\cellcolor{lightgray!10}\\textbf{8440} & \\cellcolor{lightgray!10}\\textbf{34.8} & \\cellcolor{lightgray!10}\\textbf{38.49} \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 54.81 & 4 & 0 & 6262 & -- & 28.31 \\\\\n\\thincline{2-8}\n & APF & 54.19 & 3.39 & 69.92 & \\textbf{8344} & \\textbf{33.24} & \\textbf{38.04} \\\\\n & AutoFreeze & 54.14 & 3.33 & 78.02 & 7925 & 26.54 & 36.14 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{55.18} & \\cellcolor{gray!15}\\underline{4.37} & \\cellcolor{gray!15}38.63 & \\cellcolor{gray!15}8133 & \\cellcolor{gray!15}29.87 & \\cellcolor{gray!15}37 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\textbf{55.23} & \\cellcolor{lightgray!10}\\textbf{4.42} & \\cellcolor{lightgray!10}\\textbf{37.69} & \\cellcolor{lightgray!10}8201 & \\cellcolor{lightgray!10}30.95 & \\cellcolor{lightgray!10}37.31 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}54.24 & \\cellcolor{lightgray!10}3.44 & \\cellcolor{lightgray!10}\\underline{38.36} & \\cellcolor{lightgray!10}\\underline{8213} & \\cellcolor{lightgray!10}\\underline{31.14} & \\cellcolor{lightgray!10}\\underline{37.39} \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 54.82 & 4.01 & 0 & 6088 & -- & 27.92 \\\\\n\\thincline{2-8}\n & APF & 54.11 & 3.3 & 74.88 & \\textbf{8350} & \\textbf{37.15} & \\textbf{38.16} \\\\\n & AutoFreeze & 53.79 & 2.98 & 79.33 & 7494 & 23.09 & 34.54 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}54.18 & \\cellcolor{gray!15}3.37 & \\cellcolor{gray!15}45.69 & \\cellcolor{gray!15}7796 & \\cellcolor{gray!15}28.05 & \\cellcolor{gray!15}\\underline{ ...
#
# \begin{table*}[t]
# \renewcommand{\arraystretch}{1}
# \centering
# \caption{Comparison of freezing methods under different pipeline schedules (LLaMA-8B).}
# \resizebox{\textwidth}{!}{
# \begin{tabular}{cl|ccc|ccc}
#
# %%%%% header %%%%%
# \hline
# \multirow{2}{*}{\makecell[c]{Pipeline \\ Schedule}} &
# \multicolumn{1}{c|}{\multirow{2}{*}{\makecell[c]{Freeze \\ Method}}} &
# \multicolumn{3}{c|}{Accuracy Preservation} &
# \multicolumn{3}{c}{Time Efficiency} \\
# \cline{3-5} \cline{6-8}
# & & Avg. Acc.↑ & Acc. Gain↑ & Freeze Ratio↓ & Throughput↑ & Th. Gain↑ & MFU↑ \\
#
#
# \hline
# \multicolumn{2}{c|}{Base Pretrained Model} & 50.81 & -- & -- & -- & -- & -- \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{GPipe}} & No Freezing & 54.95 & 4.14 & 0 & 6261 & -- & 28.3 \\
# \thincline{2-8}
#  & APF & \underline{54.49} & \underline{3.69} & 70.53 & \underline{8360} & \underline{33.51} & \underline{38.13} \\
#  & AutoFreeze & \textbf{54.54} & \textbf{3.73} & 81.95 & 8052 & 28.59 & 36.72 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}53.98 & \cellcolor{gray!15}3.17 & \cellcolor{gray!15}\textbf{38.84} & \cellcolor{gray!15}7412 & \cellcolor{gray!15}18.37 & \cellcolor{gray!15}33.58 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}54.09 & \cellcolor{lightgray!10}3.28 & \cellcolor{lightgray!10}\underline{39.19} & \cellcolor{lightgray!10}7432 & \cellcolor{lightgray!10}18.69 & \cellcolor{lightgray!10}33.67 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}54.21 & \cellcolor{lightgray!10}3.4 & \cellcolor{lightgray!10}43.27 & \cellcolor{lightgray!10}\textbf{8440} & \cellcolor{lightgray!10}\textbf{34.8} & \cellcolor{lightgray!10}\textbf{38.49} \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{1F1B}} & No Freezing & 54.81 & 4 & 0 & 6262 & -- & 28.31 \\
# \thincline{2-8}
#  & APF & 54.19 & 3.39 & 69.92 & \textbf{8344} & \textbf{33.24} & \textbf{38.04} \\
#  & AutoFreeze & 54.14 & 3.33 & 78.02 & 7925 & 26.54 & 36.14 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\underline{55.18} & \cellcolor{gray!15}\underline{4.37} & \cellcolor{gray!15}38.63 & \cellcolor{gray!15}8133 & \cellcolor{gray!15}29.87 & \cellcolor{gray!15}37 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\textbf{55.23} & \cellcolor{lightgray!10}\textbf{4.42} & \cellcolor{lightgray!10}\textbf{37.69} & \cellcolor{lightgray!10}8201 & \cellcolor{lightgray!10}30.95 & \cellcolor{lightgray!10}37.31 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}54.24 & \cellcolor{lightgray!10}3.44 & \cellcolor{lightgray!10}\underline{38.36} & \cellcolor{lightgray!10}\underline{8213} & \cellcolor{lightgray!10}\underline{31.14} & \cellcolor{lightgray!10}\underline{37.39} \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{Interleaved\\1F1B}} & No Freezing & 54.82 & 4.01 & 0 & 6088 & -- & 27.92 \\
# \thincline{2-8}
#  & APF & 54.11 & 3.3 & 74.88 & \textbf{8350} & \textbf{37.15} & \textbf{38.16} \\
#  & AutoFreeze & 53.79 & 2.98 & 79.33 & 7494 & 23.09 & 34.54 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}54.18 & \cellcolor{gray!15}3.37 & \cellcolor{gray!15}45.69 & \cellcolor{gray!15}7796 & \cellcolor{gray!15}28.05 & \cellcolor{gray!15}\underline{35.89} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\textbf{54.35} & \cellcolor{lightgray!10}\textbf{3.54} & \cellcolor{lightgray!10}\textbf{44.3} & \cellcolor{lightgray!10}7738 & \cellcolor{lightgray!10}27.09 & \cellcolor{lightgray!10}35.16 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}\underline{54.33} & \cellcolor{lightgray!10}\underline{3.52} & \cellcolor{lightgray!10}\underline{44.66} & \cellcolor{lightgray!10}\underline{7797} & \cellcolor{lightgray!10}\underline{28.07} & \cellcolor{lightgray!10}35.44 \\
# \hline
#
#
# \end{tabular}}
# \label{tab:llama8b}
# \end{table*}

# %%
# Benchmark score
caption = "Detailed Benchmark Scores under different pipeline schedules (LLaMA-8B)."
label = "llama8b_benchmark"
output_file = label + "_table.txt"

latex_str = raw_to_latex_table(input_string,
	col_names=["pipeline", "method", "config", "mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	numeric_cols=["mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	columns=["pipeline","method","mmlu","hella","arc","tqa","avg_acc"],
	datarow_cols=["mmlu", "hella", "arc", "tqa", "avg_acc"],
	header=benchmark_header(caption),
	footer=benchmark_footer(label),
)
print(latex_str)
print(latex_str, file=open(output_file, "w"))
# Out:
# curr_pipe: None, r: {'pipeline': 'Base Pretrained Model', 'method': '', 'mmlu': 63.55, 'hella': 60.0, 'arc': 51.28, 'tqa': 28.4, 'avg_acc': 50.81}
# curr_pipe: Base Pretrained Model, r: {'pipeline': 'GPipe', 'method': 'No Freezing', 'mmlu': 64.24, 'hella': 60.43, 'arc': 56.06, 'tqa': 39.05, 'avg_acc': 54.95}
# curr_pipe: GPipe, r: {'pipeline': '1F1B', 'method': 'No Freezing', 'mmlu': 64.15, 'hella': 60.49, 'arc': 55.55, 'tqa': 39.05, 'avg_acc': 54.81}
# c: arc values: dict_values([55.12, 54.86, 54.44, 53.67, 54.01]) best: 55.12 second_best: 54.86
# c: hella values: dict_values([61.34, 60.86, 61.06, 61.0, 61.04]) best: 61.34 second_best: 61.06
# c: mmlu values: dict_values([63.69, 64.61, 63.93, 64.1, 64.2]) best: 64.61 second_best: 64.2
# c: avg_acc values: dict_values([54.49, 54.54, 53.98, 54.09, 54.21]) best: 54.54 second_best: 54.49
# c: tqa values: dict_values([37.82, 37.82, 36.47, 37.58, 37.58]) best: 37.82 second_best: 37.82
# pipe: GPipe, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 64.24 & 60.43 & 56.06 & 39.05 & 54.95 \\\\', '\\thincline{2-7}', ' & APF & 63.69 & \\textbf{61.34} & \\textbf{55.12} & \\textbf{37.82} & \\underline{54.49} \\\\', ' & AutoFreeze & \\textbf{64.61} & 60.86 & \\underline{54.86} & \\textbf{37.82} & \\textbf{54.54} \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}63.93 & \\cellcolor{gray!15}\\underline{61.06} & \\cellcolor{gray!15}54.44 & \\cellcolor{gray!15}36.47 & \\cellcolor{gray!15}53.98 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}64.1 & \\cellcolor{lightgray!10}61 & \\cellcolor{lightgray!10}53.67 & \\cellcolor{lightgray!10}37.58 & \\cellcolor{lightgray!10}54.09 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\underline{64.2} & \\cellcolor{lightgray!10}61.04 & \\cellcolor{lightgray!10}54.01 & \\cellcolor{lightgray!10}37.58 & \\cellcolor{lightgray!10}54.21 \\\\']
# curr_pipe: 1F1B, r: {'pipeline': 'Interleaved 1F1B', 'method': 'No Freezing', 'mmlu': 64.38, 'hella': 60.35, 'arc': 55.63, 'tqa': 38.92, 'avg_acc': 54.82}
# c: arc values: dict_values([54.78, 54.1, 55.72, 55.2, 54.44]) best: 55.72 second_best: 55.2
# c: hella values: dict_values([61.27, 60.7, 60.56, 60.91, 60.83]) best: 61.27 second_best: 60.91
# c: mmlu values: dict_values([64.25, 64.18, 64.54, 64.29, 64.37]) best: 64.54 second_best: 64.37
# c: avg_acc values: dict_values([54.19, 54.14, 55.18, 55.23, 54.24]) best: 55.23 second_best: 55.18
# c: tqa values: dict_values([36.47, 37.58, 39.9, 40.51, 37.33]) best: 40.51 second_best: 39.9
# pipe: 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 64.15 & 60.49 & 55.55 & 39.05 & 54.81 \\\\', '\\thincline{2-7}', ' & APF & 64.25 & \\textbf{61.27} & 54.78 & 36.47 & 54.19 \\\\', ' & AutoFreeze & 64.18 & 60.7 & 54.1 & 37.58 & 54.14 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{64.54} & \\cellcolor{gray!15}60.56 & \\cellcolor{gray!15}\\textbf{55.72} & \\cellcolor{gray!15}\\underline{39.9} & \\cellcolor{gray!15}\\underline{55.18} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}64.29 & \\cellcolor{lightgray!10}\\underline{60.91} & \\cellcolor{lightgray!10}\\underline{55.2} & \\cellcolor{lightgray!10}\\textbf{40.51} & \\cellcolor{lightgray!10}\\textbf{55.23} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\underline{64.37} & \\cellcolor{lightgray!10}60.83 & \\cellcolor{lightgray!10}54.44 & \\cellcolor{lightgray!10}37.33 & \\cellcolor{lightgray!10}54.24 \\\\']
# c: arc values: dict_values([54.86, 54.18, 54.61, 54.44, 54.1]) best: 54.86 second_best: 54.61
# c: hella values: dict_values([61.17, 61.0, 60.9, 60.91, 60.98]) best: 61.17 second_best: 61.0
# c: mmlu values: dict_values([64.04, 64.24, 64.61, 64.71, 64.91]) best: 64.91 second_best: 64.71
# c: avg_acc values: dict_values([54.11, 53.79, 54.18, 54.35, 54.33]) best: 54.35 second_best: 54.33
# c: tqa values: dict_values([36.35, 35.74, 36.6, 37.33, 37.33]) best: 37.33 second_best: 37.33
# pipe: Interleaved 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 64.38 & 60.35 & 55.63 & 38.92 & 54.82 \\\\', '\\thincline{2-7}', ' & APF & 64.04 & \\textbf{61.17} & \\textbf{54.86} & 36.35 & 54.11 \\\\', ' & AutoFreeze & 64.24 & \\underline{61} & 54.18 & 35.74 & 53.79 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}64.61 & \\cellcolor{gray!15}60.9 & \\cellcolor{gray!15}\\underline{54.61} & \\cellcolor{gray!15}36.6 & \\cellcolor{gray!15}54.18 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{64.71} & \\cellcolor{lightgray!10}60.91 & \\cellcolor{lightgray!10}54.44 & \\cellcolor{lightgray!10}\\textbf{37.33} & \\cellcolor{lightgray!10}\\textbf{54.35} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\textbf{64.91} & \\cellcolor{lightgray!10}60.98 & \\cellcolor{lightgray!10}54.1 & \\cellcolor{lightgray!10}\\textbf{37.33} & \\cellcolor{lightgray!10}\\underline{54.33} \\\\']
# final latex:  ['\n\\begin{table*}[t]\n\\renewcommand{\\arraystretch}{1}\n\\centering\n\\caption{Detailed Benchmark Scores under different pipeline schedules (LLaMA-8B).}\\resizebox{0.85\\linewidth}{!}{\n\\begin{tabular}{cl|cccc|c}\n\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%% Header %%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\hline\n\\multirow{3}{*}{\\makecell[c]{Pipeline \\\\Schedule }} &\n\\multicolumn{1}{c|}{\\multirow{3}{*}{\\makecell[c]{Freeze \\\\Method }}} &\n\\multicolumn{4}{c|}{Benchmark Scores (\\%) ↑} &\n\\multirow{3}{*}{\\makecell[c]{Average \\\\Accuracy↑ }} \\\\\n\\cline{3-6}\n& & \\makecell[c]{MMLU\\\\[-5pt]\\scriptsize{(5 shots)}} &\n\\makecell[c]{HellaSwag\\\\[-5pt]\\scriptsize{(0 shots)}} &\n\\makecell[c]{ARC-C\\\\[-5pt]\\scriptsize{(10 shots)}} &\n\\makecell[c]{TruthfulQA\\\\[-5pt]\\scriptsize{(0 shots)}} \\\\\n\n', '\\hline', '\\multicolumn{2}{c|}{Base Pretrained Model} & 63.55 & 60 & 51.28 & 28.4 & 50.81 \\\\', '\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 64.24 & 60.43 & 56.06 & 39.05 & 54.95 \\\\\n\\thincline{2-7}\n & APF & 63.69 & \\textbf{61.34} & \\textbf{55.12} & \\textbf{37.82} & \\underline{54.49} \\\\\n & AutoFreeze & \\textbf{64.61} & 60.86 & \\underline{54.86} & \\textbf{37.82} & \\textbf{54.54} \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}63.93 & \\cellcolor{gray!15}\\underline{61.06} & \\cellcolor{gray!15}54.44 & \\cellcolor{gray!15}36.47 & \\cellcolor{gray!15}53.98 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}64.1 & \\cellcolor{lightgray!10}61 & \\cellcolor{lightgray!10}53.67 & \\cellcolor{lightgray!10}37.58 & \\cellcolor{lightgray!10}54.09 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\underline{64.2} & \\cellcolor{lightgray!10}61.04 & \\cellcolor{lightgray!10}54.01 & \\cellcolor{lightgray!10}37.58 & \\cellcolor{lightgray!10}54.21 \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 64.15 & 60.49 & 55.55 & 39.05 & 54.81 \\\\\n\\thincline{2-7}\n & APF & 64.25 & \\textbf{61.27} & 54.78 & 36.47 & 54.19 \\\\\n & AutoFreeze & 64.18 & 60.7 & 54.1 & 37.58 & 54.14 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{64.54} & \\cellcolor{gray!15}60.56 & \\cellcolor{gray!15}\\textbf{55.72} & \\cellcolor{gray!15}\\underline{39.9} & \\cellcolor{gray!15}\\underline{55.18} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}64.29 & \\cellcolor{lightgray!10}\\underline{60.91} & \\cellcolor{lightgray!10}\\underline{55.2} & \\cellcolor{lightgray!10}\\textbf{40.51} & \\cellcolor{lightgray!10}\\textbf{55.23} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\underline{64.37} & \\cellcolor{lightgray!10}60.83 & \\cellcolor{lightgray!10}54.44 & \\cellcolor{lightgray!10}37.33 & \\cellcolor{lightgray!10}54.24 \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 64.38 & 60.35 & 55.63 & 38.92 & 54.82 \\\\\n\\thincline{2-7}\n & APF & 64.04 & \\textbf{61.17} & \\textbf{54.86} & 36.35 & 54.11 \\\\\n & AutoFreeze & 64.24 & \\underline{61} & 54.18 & 35.74 & 53.79 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}64.61 & \\cellcolor{gray!15}60.9 & \\cellcolor{gray!15}\\underline{54 ...
#
# \begin{table*}[t]
# \renewcommand{\arraystretch}{1}
# \centering
# \caption{Detailed Benchmark Scores under different pipeline schedules (LLaMA-8B).}\resizebox{0.85\linewidth}{!}{
# \begin{tabular}{cl|cccc|c}
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%% Header %%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \hline
# \multirow{3}{*}{\makecell[c]{Pipeline \\Schedule }} &
# \multicolumn{1}{c|}{\multirow{3}{*}{\makecell[c]{Freeze \\Method }}} &
# \multicolumn{4}{c|}{Benchmark Scores (\%) ↑} &
# \multirow{3}{*}{\makecell[c]{Average \\Accuracy↑ }} \\
# \cline{3-6}
# & & \makecell[c]{MMLU\\[-5pt]\scriptsize{(5 shots)}} &
# \makecell[c]{HellaSwag\\[-5pt]\scriptsize{(0 shots)}} &
# \makecell[c]{ARC-C\\[-5pt]\scriptsize{(10 shots)}} &
# \makecell[c]{TruthfulQA\\[-5pt]\scriptsize{(0 shots)}} \\
#
#
# \hline
# \multicolumn{2}{c|}{Base Pretrained Model} & 63.55 & 60 & 51.28 & 28.4 & 50.81 \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{GPipe}} & No Freezing & 64.24 & 60.43 & 56.06 & 39.05 & 54.95 \\
# \thincline{2-7}
#  & APF & 63.69 & \textbf{61.34} & \textbf{55.12} & \textbf{37.82} & \underline{54.49} \\
#  & AutoFreeze & \textbf{64.61} & 60.86 & \underline{54.86} & \textbf{37.82} & \textbf{54.54} \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}63.93 & \cellcolor{gray!15}\underline{61.06} & \cellcolor{gray!15}54.44 & \cellcolor{gray!15}36.47 & \cellcolor{gray!15}53.98 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}64.1 & \cellcolor{lightgray!10}61 & \cellcolor{lightgray!10}53.67 & \cellcolor{lightgray!10}37.58 & \cellcolor{lightgray!10}54.09 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}\underline{64.2} & \cellcolor{lightgray!10}61.04 & \cellcolor{lightgray!10}54.01 & \cellcolor{lightgray!10}37.58 & \cellcolor{lightgray!10}54.21 \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{1F1B}} & No Freezing & 64.15 & 60.49 & 55.55 & 39.05 & 54.81 \\
# \thincline{2-7}
#  & APF & 64.25 & \textbf{61.27} & 54.78 & 36.47 & 54.19 \\
#  & AutoFreeze & 64.18 & 60.7 & 54.1 & 37.58 & 54.14 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\textbf{64.54} & \cellcolor{gray!15}60.56 & \cellcolor{gray!15}\textbf{55.72} & \cellcolor{gray!15}\underline{39.9} & \cellcolor{gray!15}\underline{55.18} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}64.29 & \cellcolor{lightgray!10}\underline{60.91} & \cellcolor{lightgray!10}\underline{55.2} & \cellcolor{lightgray!10}\textbf{40.51} & \cellcolor{lightgray!10}\textbf{55.23} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}\underline{64.37} & \cellcolor{lightgray!10}60.83 & \cellcolor{lightgray!10}54.44 & \cellcolor{lightgray!10}37.33 & \cellcolor{lightgray!10}54.24 \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{Interleaved\\1F1B}} & No Freezing & 64.38 & 60.35 & 55.63 & 38.92 & 54.82 \\
# \thincline{2-7}
#  & APF & 64.04 & \textbf{61.17} & \textbf{54.86} & 36.35 & 54.11 \\
#  & AutoFreeze & 64.24 & \underline{61} & 54.18 & 35.74 & 53.79 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}64.61 & \cellcolor{gray!15}60.9 & \cellcolor{gray!15}\underline{54.61} & \cellcolor{gray!15}36.6 & \cellcolor{gray!15}54.18 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\underline{64.71} & \cellcolor{lightgray!10}60.91 & \cellcolor{lightgray!10}54.44 & \cellcolor{lightgray!10}\textbf{37.33} & \cellcolor{lightgray!10}\textbf{54.35} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}\textbf{64.91} & \cellcolor{lightgray!10}60.98 & \cellcolor{lightgray!10}54.1 & \cellcolor{lightgray!10}\textbf{37.33} & \cellcolor{lightgray!10}\underline{54.33} \\
# \hline
#
#
# \end{tabular}}
# \label{tab:llama8b_benchmark}
# \end{table*}

# %%
caption = "Comparison of freezing methods under different pipeline schedules (LLaMA-1B)."
label = "llama1b"
output_file = label + "_table_1227.txt"

input_string = """
"Pipeline 
Schedule"	Freeze Method		Accuracy Preservation							Time Efficiency			
			"MMLU
(5 shots)
 ↑"	"HellaSwag
 ↑"	"ARC-C
(10 shots)
 ↑"	"TruthfulQA
 ↑"	"Average
Acc.↑"	"Accuracy
Gain (%p) ↑"	"Avg. Freeze 
Ratio (%) ↓"	"Avg. 
Throughput 
(token/s) ↑"	"Throughput
Gain (%) ↑"	Avg. mfu (%) ↑	"Avg. Batch
Time (s) ↓"
Base Pretrained Model			31.99%	47.75%	36.95%	23.01%	34.93%		-				
GPipe	No Freezing		33.07%	49.37%	37.54%	28.40%	37.10%	36.35%	0.00%	6937.35 	-	16.00 	4.72 
	APF	th=0.01	32.79%	48.53%	37.03%	25.21%	35.89%	35.14%	70.35%	8159.60 	17.62 	18.75 	4.02 
	AutoFreeze	p=80%	30.64%	48.80%	38.05%	26.56%	36.01%	35.26%	55.93%	7679.16 	10.69 	17.66 	4.27 
	TimelyFreeze	mfr=0.8	32.13%	49.33%	37.97%	28.27%	36.93%	36.18%	39.86%	8819.64 	27.13 	20.27 	3.72 
	TimelyFreeze+APF	mfr=0.8, th=0.01	31.26%	48.83%	37.37%	26.56%	36.01%	35.26%	40.50%	8818.68 	27.12 	20.31 	3.72 
	TimelyFreeze+AutoFreeze	mfr=0.8, p=80%	30.55%	48.97%	37.46%	26.56%	35.89%	35.14%	36.95%	8799.47 	26.84 	20.27 	3.72 
1F1B	No Freezing		31.51%	49.58%	37.71%	25.95%	36.19%	35.44%	0.00%	7140.05 	-	16.43 	4.59 
	APF	th=0.01	32.52%	48.38%	36.86%	25.09%	35.71%	34.96%	70.03%	8217.45 	15.09 	18.90 	3.99 
	AutoFreeze	p=80%	28.65%	42.07%	37.54%	26.81%	33.77%	33.02%	50.32%	7605.43 	6.52 	17.48 	4.31 
	TimelyFreeze	mfr=0.8	29.80%	49.04%	37.03%	26.56%	35.61%	34.86%	31.14%	9224.38 	29.19 	21.24 	3.55 
	TimelyFreeze+APF	mfr=0.8, th=0.01	28.47%	49.08%	36.77%	26.44%	35.19%	34.44%	31.07%	9146.56 	28.10 	21.06 	3.58 
	TimelyFreeze+AutoFreeze	mfr=0.8, p=80%	26.93%	48.97%	37.46%	25.95%	34.83%	34.08%	31.06%	9176.37 	28.52 	21.15 	3.57 
Interleaved 1F1B	No Freezing		30.64%	49.71%	37.80%	27.05%	36.30%	35.55%	0.00%	6776.70 	-	15.63 	4.84 
	APF	th=0.01	32.64%	48.40%	36.95%	25.21%	35.80%	35.05%	69.05%	7442.39 	9.82 	17.13 	4.40 
	AutoFreeze	p=80%	28.80%	42.12%	37.71%	26.68%	33.83%	33.08%	39.18%	6931.66 	2.29 	15.98 	4.73 
	TimelyFreeze	mfr=0.8	27.13%	48.93%	38.05%	25.83%	34.99%	34.24%	36.63%	8256.26 	21.83 	19.00 	3.97 
	TimelyFreeze+APF	mfr=0.8, th=0.01	28.36%	48.90%	37.88%	25.46%	35.15%	34.40%	38.56%	8138.26 	20.09 	18.73 	4.03 
	TimelyFreeze+AutoFreeze	mfr=0.8, p=80%	30.68%	49.36%	37.88%	26.07%	36.00%	35.25%	38.63%	8245.69 	21.68 	18.98 	3.97 
ZeroBubbleZBV	No Freezing		31.31%	49.79%	38.23%	27.17%	36.63%	35.88%	0.00%	7475.52 	-	17.16 	4.38 
	APF	th=0.01	32.35%	48.20%	37.12%	24.60%	35.57%	34.82%	65.51%	9638.23 	28.93 	22.12 	3.40 
	AutoFreeze	p=80%	28.95%	47.35%	37.63%	26.56%	35.12%	34.37%	26.56%	7928.64 	6.06 	18.17 	4.13 
	TimelyFreeze	mfr=0.8	31.98%	49.38%	38.65%	27.29%	36.83%	36.08%	40.28%	9705.36 	29.83 	22.26 	3.38 
	TimelyFreeze+APF	mfr=0.8, th=0.01	29.49%	49.09%	38.91%	25.21%	35.68%	34.93%	40.15%	9542.33 	27.65 	21.92 	3.43 
	TimelyFreeze+AutoFreeze	mfr=0.8, p=80%	28.26%	48.75%	38.31%	25.46%	35.20%	34.45%	40.22%	9663.72 	29.27 	22.19 	3.39 
 
"""

latex_str = raw_to_latex_table(input_string,
	col_names=["pipeline", "method", "config", "mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	numeric_cols=["mmlu", "hella", "arc", "tqa", "avg_acc", "acc_gain", "freeze", "throughput", "tp_gain", "mfu", "batch"],
	columns=["pipeline","method","avg_acc","acc_gain","freeze","throughput","tp_gain","mfu"],
	header=main_result_header(caption),
	footer=main_result_footer(label),
)
print(latex_str)
print(latex_str, file=open(output_file, "w"))
# Out:
# curr_pipe: None, r: {'pipeline': 'Base Pretrained Model', 'method': '', 'avg_acc': 34.93, 'acc_gain': '', 'freeze': '', 'throughput': '', 'tp_gain': '', 'mfu': ''}
# curr_pipe: Base Pretrained Model, r: {'pipeline': 'GPipe', 'method': 'No Freezing', 'avg_acc': 37.1, 'acc_gain': 36.35, 'freeze': 0.0, 'throughput': 6937.35, 'tp_gain': '', 'mfu': 16.0}
# curr_pipe: GPipe, r: {'pipeline': '1F1B', 'method': 'No Freezing', 'avg_acc': 36.19, 'acc_gain': 35.44, 'freeze': 0.0, 'throughput': 7140.05, 'tp_gain': '', 'mfu': 16.43}
# c: freeze values: dict_values([70.35, 55.93, 39.86, 40.5, 36.95]) best: 36.95 second_best: 39.86
# c: acc_gain values: dict_values([35.14, 35.26, 36.18, 35.26, 35.14]) best: 36.18 second_best: 35.26
# c: tp_gain values: dict_values([17.62, 10.69, 27.13, 27.12, 26.84]) best: 27.13 second_best: 27.12
# c: avg_acc values: dict_values([35.89, 36.01, 36.93, 36.01, 35.89]) best: 36.93 second_best: 36.01
# c: mfu values: dict_values([18.75, 17.66, 20.27, 20.31, 20.27]) best: 20.31 second_best: 20.27
# c: throughput values: dict_values([8159.6, 7679.16, 8819.64, 8818.68, 8799.47]) best: 8819.64 second_best: 8818.68
# pipe: GPipe, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 37.1 & 36.35 & 0 & 6937.35 & -- & 16 \\\\', '\\thincline{2-8}', ' & APF & 35.89 & 35.14 & 70.35 & 8159.6 & 17.62 & 18.75 \\\\', ' & AutoFreeze & \\underline{36.01} & \\underline{35.26} & 55.93 & 7679.16 & 10.69 & 17.66 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{36.93} & \\cellcolor{gray!15}\\textbf{36.18} & \\cellcolor{gray!15}\\underline{39.86} & \\cellcolor{gray!15}\\textbf{8819.64} & \\cellcolor{gray!15}\\textbf{27.13} & \\cellcolor{gray!15}\\underline{20.27} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{36.01} & \\cellcolor{lightgray!10}\\underline{35.26} & \\cellcolor{lightgray!10}40.5 & \\cellcolor{lightgray!10}\\underline{8818.68} & \\cellcolor{lightgray!10}\\underline{27.12} & \\cellcolor{lightgray!10}\\textbf{20.31} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}35.89 & \\cellcolor{lightgray!10}35.14 & \\cellcolor{lightgray!10}\\textbf{36.95} & \\cellcolor{lightgray!10}8799.47 & \\cellcolor{lightgray!10}26.84 & \\cellcolor{lightgray!10}\\underline{20.27} \\\\']
# curr_pipe: 1F1B, r: {'pipeline': 'Interleaved 1F1B', 'method': 'No Freezing', 'avg_acc': 36.3, 'acc_gain': 35.55, 'freeze': 0.0, 'throughput': 6776.7, 'tp_gain': '', 'mfu': 15.63}
# c: freeze values: dict_values([70.03, 50.32, 31.14, 31.07, 31.06]) best: 31.06 second_best: 31.07
# c: acc_gain values: dict_values([34.96, 33.02, 34.86, 34.44, 34.08]) best: 34.96 second_best: 34.86
# c: tp_gain values: dict_values([15.09, 6.52, 29.19, 28.1, 28.52]) best: 29.19 second_best: 28.52
# c: avg_acc values: dict_values([35.71, 33.77, 35.61, 35.19, 34.83]) best: 35.71 second_best: 35.61
# c: mfu values: dict_values([18.9, 17.48, 21.24, 21.06, 21.15]) best: 21.24 second_best: 21.15
# c: throughput values: dict_values([8217.45, 7605.43, 9224.38, 9146.56, 9176.37]) best: 9224.38 second_best: 9176.37
# pipe: 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 36.19 & 35.44 & 0 & 7140.05 & -- & 16.43 \\\\', '\\thincline{2-8}', ' & APF & \\textbf{35.71} & \\textbf{34.96} & 70.03 & 8217.45 & 15.09 & 18.9 \\\\', ' & AutoFreeze & 33.77 & 33.02 & 50.32 & 7605.43 & 6.52 & 17.48 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{35.61} & \\cellcolor{gray!15}\\underline{34.86} & \\cellcolor{gray!15}31.14 & \\cellcolor{gray!15}\\textbf{9224.38} & \\cellcolor{gray!15}\\textbf{29.19} & \\cellcolor{gray!15}\\textbf{21.24} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}35.19 & \\cellcolor{lightgray!10}34.44 & \\cellcolor{lightgray!10}\\underline{31.07} & \\cellcolor{lightgray!10}9146.56 & \\cellcolor{lightgray!10}28.1 & \\cellcolor{lightgray!10}21.06 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}34.83 & \\cellcolor{lightgray!10}34.08 & \\cellcolor{lightgray!10}\\textbf{31.06} & \\cellcolor{lightgray!10}\\underline{9176.37} & \\cellcolor{lightgray!10}\\underline{28.52} & \\cellcolor{lightgray!10}\\underline{21.15} \\\\']
# curr_pipe: Interleaved 1F1B, r: {'pipeline': 'ZeroBubbleZBV', 'method': 'No Freezing', 'avg_acc': 36.63, 'acc_gain': 35.88, 'freeze': 0.0, 'throughput': 7475.52, 'tp_gain': '', 'mfu': 17.16}
# c: freeze values: dict_values([69.05, 39.18, 36.63, 38.56, 38.63]) best: 36.63 second_best: 38.56
# c: acc_gain values: dict_values([35.05, 33.08, 34.24, 34.4, 35.25]) best: 35.25 second_best: 35.05
# c: tp_gain values: dict_values([9.82, 2.29, 21.83, 20.09, 21.68]) best: 21.83 second_best: 21.68
# c: avg_acc values: dict_values([35.8, 33.83, 34.99, 35.15, 36.0]) best: 36.0 second_best: 35.8
# c: mfu values: dict_values([17.13, 15.98, 19.0, 18.73, 18.98]) best: 19.0 second_best: 18.98
# c: throughput values: dict_values([7442.39, 6931.66, 8256.26, 8138.26, 8245.69]) best: 8256.26 second_best: 8245.69
# pipe: Interleaved 1F1B, latex: ['\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%', '%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%', '\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 36.3 & 35.55 & 0 & 6776.7 & -- & 15.63 \\\\', '\\thincline{2-8}', ' & APF & \\underline{35.8} & \\underline{35.05} & 69.05 & 7442.39 & 9.82 & 17.13 \\\\', ' & AutoFreeze & 33.83 & 33.08 & 39.18 & 6931.66 & 2.29 & 15.98 \\\\', ' & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}34.99 & \\cellcolor{gray!15}34.24 & \\cellcolor{gray!15}\\textbf{36.63} & \\cellcolor{gray!15}\\textbf{8256.26} & \\cellcolor{gray!15}\\textbf{21.83} & \\cellcolor{gray!15}\\textbf{19} \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}35.15 & \\cellcolor{lightgray!10}34.4 & \\cellcolor{lightgray!10}\\underline{38.56} & \\cellcolor{lightgray!10}8138.26 & \\cellcolor{lightgray!10}20.09 & \\cellcolor{lightgray!10}18.73 \\\\', ' & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}\\textbf{36} & \\cellcolor{lightgray!10}\\textbf{35.25} & \\cellcolor{lightgray!10}38.63 & \\cellcolor{lightgray!10}\\underline{8245.69} & \\cellcolor{lightgray!10}\\underline{21.68} & \\cellcolor{lightgray!10}\\underline{18.98} \\\\']
# final latex:  ['\n\\begin{table*}[t]\n\\renewcommand{\\arraystretch}{1}\n\\centering\n\\caption{Comparison of freezing methods under different pipeline schedules (LLaMA-1B).}\n\\resizebox{\\textwidth}{!}{\n\\begin{tabular}{cl|ccc|ccc}\n\n%%%%% header %%%%%\n\\hline\n\\multirow{2}{*}{\\makecell[c]{Pipeline \\\\ Schedule}} &\n\\multicolumn{1}{c|}{\\multirow{2}{*}{\\makecell[c]{Freeze \\\\ Method}}} &\n\\multicolumn{3}{c|}{Accuracy Preservation} &\n\\multicolumn{3}{c}{Time Efficiency} \\\\\n\\cline{3-5} \\cline{6-8}\n& & Avg. Acc.↑ & Acc. Gain↑ & Freeze Ratio↓ & Throughput↑ & Th. Gain↑ & MFU↑ \\\\\n\n', '\\hline', '\\multicolumn{2}{c|}{Base Pretrained Model} & 34.93 & -- & -- & -- & -- & -- \\\\', '\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{GPipe}} & No Freezing & 37.1 & 36.35 & 0 & 6937.35 & -- & 16 \\\\\n\\thincline{2-8}\n & APF & 35.89 & 35.14 & 70.35 & 8159.6 & 17.62 & 18.75 \\\\\n & AutoFreeze & \\underline{36.01} & \\underline{35.26} & 55.93 & 7679.16 & 10.69 & 17.66 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\textbf{36.93} & \\cellcolor{gray!15}\\textbf{36.18} & \\cellcolor{gray!15}\\underline{39.86} & \\cellcolor{gray!15}\\textbf{8819.64} & \\cellcolor{gray!15}\\textbf{27.13} & \\cellcolor{gray!15}\\underline{20.27} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}\\underline{36.01} & \\cellcolor{lightgray!10}\\underline{35.26} & \\cellcolor{lightgray!10}40.5 & \\cellcolor{lightgray!10}\\underline{8818.68} & \\cellcolor{lightgray!10}\\underline{27.12} & \\cellcolor{lightgray!10}\\textbf{20.31} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}35.89 & \\cellcolor{lightgray!10}35.14 & \\cellcolor{lightgray!10}\\textbf{36.95} & \\cellcolor{lightgray!10}8799.47 & \\cellcolor{lightgray!10}26.84 & \\cellcolor{lightgray!10}\\underline{20.27} \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{1F1B}} & No Freezing & 36.19 & 35.44 & 0 & 7140.05 & -- & 16.43 \\\\\n\\thincline{2-8}\n & APF & \\textbf{35.71} & \\textbf{34.96} & 70.03 & 8217.45 & 15.09 & 18.9 \\\\\n & AutoFreeze & 33.77 & 33.02 & 50.32 & 7605.43 & 6.52 & 17.48 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}\\underline{35.61} & \\cellcolor{gray!15}\\underline{34.86} & \\cellcolor{gray!15}31.14 & \\cellcolor{gray!15}\\textbf{9224.38} & \\cellcolor{gray!15}\\textbf{29.19} & \\cellcolor{gray!15}\\textbf{21.24} \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +APF & \\cellcolor{lightgray!10}35.19 & \\cellcolor{lightgray!10}34.44 & \\cellcolor{lightgray!10}\\underline{31.07} & \\cellcolor{lightgray!10}9146.56 & \\cellcolor{lightgray!10}28.1 & \\cellcolor{lightgray!10}21.06 \\\\\n & \\cellcolor{lightgray!10}\\scriptsize\\quad +AutoFreeze & \\cellcolor{lightgray!10}34.83 & \\cellcolor{lightgray!10}34.08 & \\cellcolor{lightgray!10}\\textbf{31.06} & \\cellcolor{lightgray!10}\\underline{9176.37} & \\cellcolor{lightgray!10}\\underline{28.52} & \\cellcolor{lightgray!10}\\underline{21.15} \\\\\n\\hline', '\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%\n%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%\n\\multirow{6}{*}{\\makecell[c]{Interleaved\\\\1F1B}} & No Freezing & 36.3 & 35.55 & 0 & 6776.7 & -- & 15.63 \\\\\n\\thincline{2-8}\n & APF & \\underline{35.8} & \\underline{35.05} & 69.05 & 7442.39 & 9.82 & 17.13 \\\\\n & AutoFreeze & 33.83 & 33.08 & 39.18 & 6931.66 & 2.29 & 15.98 \\\\\n & \\cellcolor{gray!15}\\TimelyFreeze{} & \\cellcolor{gray!15}34.99 & \\cellcolor{gray!15}34.24 & \\cellcolor{gray!15}\\t ...
#
# \begin{table*}[t]
# \renewcommand{\arraystretch}{1}
# \centering
# \caption{Comparison of freezing methods under different pipeline schedules (LLaMA-1B).}
# \resizebox{\textwidth}{!}{
# \begin{tabular}{cl|ccc|ccc}
#
# %%%%% header %%%%%
# \hline
# \multirow{2}{*}{\makecell[c]{Pipeline \\ Schedule}} &
# \multicolumn{1}{c|}{\multirow{2}{*}{\makecell[c]{Freeze \\ Method}}} &
# \multicolumn{3}{c|}{Accuracy Preservation} &
# \multicolumn{3}{c}{Time Efficiency} \\
# \cline{3-5} \cline{6-8}
# & & Avg. Acc.↑ & Acc. Gain↑ & Freeze Ratio↓ & Throughput↑ & Th. Gain↑ & MFU↑ \\
#
#
# \hline
# \multicolumn{2}{c|}{Base Pretrained Model} & 34.93 & -- & -- & -- & -- & -- \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% GPipe %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{GPipe}} & No Freezing & 37.1 & 36.35 & 0 & 6937.35 & -- & 16 \\
# \thincline{2-8}
#  & APF & 35.89 & 35.14 & 70.35 & 8159.6 & 17.62 & 18.75 \\
#  & AutoFreeze & \underline{36.01} & \underline{35.26} & 55.93 & 7679.16 & 10.69 & 17.66 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\textbf{36.93} & \cellcolor{gray!15}\textbf{36.18} & \cellcolor{gray!15}\underline{39.86} & \cellcolor{gray!15}\textbf{8819.64} & \cellcolor{gray!15}\textbf{27.13} & \cellcolor{gray!15}\underline{20.27} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}\underline{36.01} & \cellcolor{lightgray!10}\underline{35.26} & \cellcolor{lightgray!10}40.5 & \cellcolor{lightgray!10}\underline{8818.68} & \cellcolor{lightgray!10}\underline{27.12} & \cellcolor{lightgray!10}\textbf{20.31} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}35.89 & \cellcolor{lightgray!10}35.14 & \cellcolor{lightgray!10}\textbf{36.95} & \cellcolor{lightgray!10}8799.47 & \cellcolor{lightgray!10}26.84 & \cellcolor{lightgray!10}\underline{20.27} \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%% 1F1B %%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{1F1B}} & No Freezing & 36.19 & 35.44 & 0 & 7140.05 & -- & 16.43 \\
# \thincline{2-8}
#  & APF & \textbf{35.71} & \textbf{34.96} & 70.03 & 8217.45 & 15.09 & 18.9 \\
#  & AutoFreeze & 33.77 & 33.02 & 50.32 & 7605.43 & 6.52 & 17.48 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}\underline{35.61} & \cellcolor{gray!15}\underline{34.86} & \cellcolor{gray!15}31.14 & \cellcolor{gray!15}\textbf{9224.38} & \cellcolor{gray!15}\textbf{29.19} & \cellcolor{gray!15}\textbf{21.24} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}35.19 & \cellcolor{lightgray!10}34.44 & \cellcolor{lightgray!10}\underline{31.07} & \cellcolor{lightgray!10}9146.56 & \cellcolor{lightgray!10}28.1 & \cellcolor{lightgray!10}21.06 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}34.83 & \cellcolor{lightgray!10}34.08 & \cellcolor{lightgray!10}\textbf{31.06} & \cellcolor{lightgray!10}\underline{9176.37} & \cellcolor{lightgray!10}\underline{28.52} & \cellcolor{lightgray!10}\underline{21.15} \\
# \hline
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%% Interleaved 1F1B %%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# \multirow{6}{*}{\makecell[c]{Interleaved\\1F1B}} & No Freezing & 36.3 & 35.55 & 0 & 6776.7 & -- & 15.63 \\
# \thincline{2-8}
#  & APF & \underline{35.8} & \underline{35.05} & 69.05 & 7442.39 & 9.82 & 17.13 \\
#  & AutoFreeze & 33.83 & 33.08 & 39.18 & 6931.66 & 2.29 & 15.98 \\
#  & \cellcolor{gray!15}\TimelyFreeze{} & \cellcolor{gray!15}34.99 & \cellcolor{gray!15}34.24 & \cellcolor{gray!15}\textbf{36.63} & \cellcolor{gray!15}\textbf{8256.26} & \cellcolor{gray!15}\textbf{21.83} & \cellcolor{gray!15}\textbf{19} \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +APF & \cellcolor{lightgray!10}35.15 & \cellcolor{lightgray!10}34.4 & \cellcolor{lightgray!10}\underline{38.56} & \cellcolor{lightgray!10}8138.26 & \cellcolor{lightgray!10}20.09 & \cellcolor{lightgray!10}18.73 \\
#  & \cellcolor{lightgray!10}\scriptsize\quad +AutoFreeze & \cellcolor{lightgray!10}\textbf{36} & \cellcolor{lightgray!10}\textbf{35.25} & \cellcolor{lightgray!10}38.63 & \cellcolor{lightgray!10}\underline{8245.69} & \cellcolor{lightgray!10}\underline{21.68} & \cellcolor{lightgray!10}\underline{18.98} \\
# \hline
#
# \end{tabular}}
# \label{tab:llama1b}
# \end{table*}
